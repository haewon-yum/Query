# %% [markdown]
# # UA Incrementality Test — Result Analysis Template
#
# **Ticket:** `{{JIRA_TICKET}}` | **Client:** `{{CLIENT_NAME}}` | **Analyst:** Haewon Yum
# **Test Period:** `{{START_DATE}}` → `{{END_DATE}}`
#
# ## Test Design
# | Field | Value |
# |---|---|
# | Type | Backend Ghost-Bid Incrementality (UPLIFT) |
# | App | `{{APP_BUNDLE}}` — `{{PLATFORM}}`, `{{COUNTRY}}` |
# | Campaign | `{{CAMPAIGN_NAME}}` (`{{CAMPAIGN_ID}}`), Goal: `{{CAMPAIGN_GOAL}}` |
# | Holdout | `{{HOLDOUT_PCT}}`% ghost-bid control / `{{TEST_PCT}}`% normal test |
# | ExpLab ID | `{{EXPERIMENT_ID}}` |
# | Groups | Control = `{{CONTROL_GROUP_ID}}` / Test = `{{TEST_GROUP_ID}}` |
# | KPI target | ≥`{{KPI_LIFT_TARGET_PCT}}`% incremental conversion lift |
#
# ## Methodology
# - **Control:** Ghost-bid users → organic baseline. **Test:** Normal bidding → ads-influenced.
# - **CPD Ratio:** Conversion-Per-Device = conversions / buckets_per_bin, compare test vs. control.
# - **Lift = CPD_test / CPD_control − 1**. Significance via 10k bootstrap resampling of bins.
#
# ## ⚠️ Method Selection
# | Experiment Type | Method | Notes |
# |---|---|---|
# | `UPLIFT` (ghost-bid) | **Bootstrap CPD** on `summary_view.experiment_summary` | Use Section 2B |
# | `GENERIC_AB_TEST` (bid strategy) | `pred_cpd_multi_metrics` | Use Section 2A |
#
# ## Table
# - `explab-298609.summary_view.experiment_summary` — per-group daily metrics

# %%
from google.cloud import bigquery
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

plt.rcParams.update({'font.size': 11, 'figure.dpi': 120})
MOLOCO_BLUE   = '#1E6FFF'
MOLOCO_ORANGE = '#FF6B35'
GRAY          = '#8C8C8C'

client = bigquery.Client(project='moloco-ods')

def run_query(query, label=''):
    df = client.query(query).result().to_dataframe()
    if label:
        print(f'✅ {label}: {len(df)} rows')
    return df

print('✅ Setup complete')

# %%
# ============================================================
# CASE PARAMETERS — update these for each incrementality test
# ============================================================
EXPERIMENT_ID   = '{{EXPERIMENT_ID}}'
EXPERIMENT_NAME = '{{EXPERIMENT_NAME}}'
CLIENT_NAME     = '{{CLIENT_NAME}}'
JIRA_TICKET     = '{{JIRA_TICKET}}'

CONTROL_GROUP_ID = 99999   # ghost-bid holdout group
TEST_GROUP_ID    = 99998   # normal bidding group

START_DATE = '{{START_DATE}}'
END_DATE   = '{{END_DATE}}'

APP_BUNDLE     = '{{APP_BUNDLE}}'
CAMPAIGN_ID    = '{{CAMPAIGN_ID}}'
CAMPAIGN_NAME  = '{{CAMPAIGN_NAME}}'
CAMPAIGN_GOAL  = '{{CAMPAIGN_GOAL}}'
PLATFORM       = '{{PLATFORM}}'
COUNTRY        = '{{COUNTRY}}'

HOLDOUT_PCT         = 5.0    # e.g. 5.0
CONTROL_BUCKET_SIZE = 50     # out of 1000 buckets (5% → 50)
TEST_BUCKET_SIZE    = 950    # out of 1000 buckets (95% → 950)
N_BINS              = 20     # number of analysis bins used
KPI_LIFT_TARGET_PCT = 20.0   # client's target

CONTROL_SHARE = CONTROL_BUCKET_SIZE / 1000
TEST_SHARE    = TEST_BUCKET_SIZE    / 1000

print(f'📋 {CLIENT_NAME} | {EXPERIMENT_ID}')
print(f'📅 {START_DATE} → {END_DATE}')
print(f'🎯 KPI target: ≥{KPI_LIFT_TARGET_PCT:.0f}%')

# %% [markdown]
# ## Section 1 — Core Metrics by Group

# %%
q_metrics = f"""
SELECT
  exp_group_id,
  CASE exp_group_id
    WHEN {CONTROL_GROUP_ID} THEN 'Control (Ghost {HOLDOUT_PCT:.0f}%)'
    WHEN {TEST_GROUP_ID}    THEN 'Test (Normal {100-HOLDOUT_PCT:.0f}%)'
  END AS group_label,
  SUM(count_bid)              AS bids,
  SUM(count_imp)              AS impressions,
  SUM(count_install)          AS installs,
  SUM(count_distinct_kpi_d7)  AS d7_distinct_actions,
  SUM(total_revenue_kpi_d7)   AS d7_revenue_usd,
  SUM(total_moloco_spent)     AS spend_usd
FROM `explab-298609.summary_view.experiment_summary`
WHERE utc_date BETWEEN '{START_DATE}' AND '{END_DATE}'
  AND exp_group_id IN ({CONTROL_GROUP_ID}, {TEST_GROUP_ID})
GROUP BY 1, 2
ORDER BY 1
"""
df_metrics = run_query(q_metrics, 'Core metrics')
display(df_metrics.T)

# %% [markdown]
# ## Section 2A — Statistical Lift (GENERIC_AB_TEST only)
#
# ⚠️ **Skip for UPLIFT ghost-bid experiments — use Section 2B instead.**
# `pred_cpd_multi_metrics` reads from `summary_v3.experiment_cumulative_summary` where `is_conducted=true`. UPLIFT experiments do NOT populate that table.

# %%
# ── For GENERIC_AB_TEST experiments only ─────────────────────
q_lift = f"""
SELECT
  metric_type,
  entity_id,
  stat_result.camp_count              AS campaign_count,
  stat_result.estimate                AS lift_ratio,
  ROUND((stat_result.estimate - 1) * 100, 2) AS lift_pct,
  stat_result.ci_lb                   AS ci_lb_ratio,
  stat_result.ci_ub                   AS ci_ub_ratio,
  ROUND((stat_result.ci_lb - 1) * 100, 2)    AS ci_lb_pct,
  ROUND((stat_result.ci_ub - 1) * 100, 2)    AS ci_ub_pct
FROM `explab-298609.summary_supplement.pred_cpd_multi_metrics`(
  DATE '{START_DATE}', DATE '{END_DATE}',
  FALSE, {CONTROL_GROUP_ID}, {TEST_GROUP_ID},
  'ALL', 'ALL', 'ALL', 'ALL', NULL, NULL, NULL, 20
)
WHERE metric_type IN ('CPD_INSTALL', 'CPD_DIST_ACT_D7', 'cROAS_D7')
ORDER BY metric_type
"""
df_lift_ab = run_query(q_lift, 'pred_cpd_multi_metrics (AB only)')
display(df_lift_ab)

# %% [markdown]
# ## Section 2B — Bootstrap CPD Lift (UPLIFT ghost-bid)
#
# **Use for `experiment_type = _UPLIFT_UI_` (ghost-bid) experiments.**
#
# Method:
# 1. Pull bin-level data from `summary_view.experiment_summary` (20 bins per group)
# 2. Normalize conversions per bucket unit: `CPD = conversions / (bucket_size / n_bins)`
# 3. Lift ratio = `mean(CPD_test) / mean(CPD_control)`
# 4. 95% CI via bootstrap resampling (10,000 iterations)

# %%
q_bins = f"""
SELECT
  exp_group_id, bin_number,
  SUM(count_install)         AS installs,
  SUM(count_distinct_kpi_d7) AS d7_distinct_actions,
  SUM(total_revenue_kpi_d7)  AS d7_revenue,
  SUM(total_moloco_spent)    AS spend_usd
FROM `explab-298609.summary_view.experiment_summary`
WHERE utc_date BETWEEN '{START_DATE}' AND '{END_DATE}'
  AND exp_group_id IN ({CONTROL_GROUP_ID}, {TEST_GROUP_ID})
GROUP BY 1, 2 ORDER BY 1, 2
"""
df_bins = run_query(q_bins, 'Bin-level data')

ctrl_bins = df_bins[df_bins.exp_group_id == CONTROL_GROUP_ID]
test_bins = df_bins[df_bins.exp_group_id == TEST_GROUP_ID]
n_bins    = len(ctrl_bins)
ctrl_bpb  = CONTROL_BUCKET_SIZE / n_bins
test_bpb  = TEST_BUCKET_SIZE    / n_bins

ctrl_cpd     = ctrl_bins['installs'].values          / ctrl_bpb
test_cpd     = test_bins['installs'].values          / test_bpb
ctrl_cpd_act = ctrl_bins['d7_distinct_actions'].values / ctrl_bpb
test_cpd_act = test_bins['d7_distinct_actions'].values / test_bpb
ctrl_cpd_rev = ctrl_bins['d7_revenue'].values         / ctrl_bpb
test_cpd_rev = test_bins['d7_revenue'].values         / test_bpb

print(f'{n_bins} bins | ctrl bpb={ctrl_bpb:.1f} | test bpb={test_bpb:.1f}')

# %%
np.random.seed(42)

def bootstrap_ratio(ctrl_vals, test_vals, n_boot=10000, alpha=0.05):
    n = len(ctrl_vals)
    rs = [np.mean(test_vals[np.random.randint(0,n,n)]) /
          max(np.mean(ctrl_vals[np.random.randint(0,n,n)]), 1e-9)
          for _ in range(n_boot)]
    rs = np.array(rs)
    return np.mean(rs), np.percentile(rs, alpha/2*100), np.percentile(rs, (1-alpha/2)*100)

r_i, lb_i, ub_i = bootstrap_ratio(ctrl_cpd,     test_cpd)
r_a, lb_a, ub_a = bootstrap_ratio(ctrl_cpd_act, test_cpd_act)
r_r, lb_r, ub_r = bootstrap_ratio(ctrl_cpd_rev, test_cpd_rev)

results = {
    'CPD_INSTALL': {
        'label': 'Install Lift\n(CPD_INSTALL)',
        'ratio': r_i, 'lb': lb_i, 'ub': ub_i,
        'lift_pct': (r_i-1)*100, 'ci_lb_pct': (lb_i-1)*100, 'ci_ub_pct': (ub_i-1)*100,
        'sig': lb_i>1.0, 'meets_target': (r_i-1)*100 >= KPI_LIFT_TARGET_PCT,
    },
    'CPD_DIST_ACT_D7': {
        'label': 'D7 Action Lift\n(CPD_DIST_ACT_D7)',
        'ratio': r_a, 'lb': lb_a, 'ub': ub_a,
        'lift_pct': (r_a-1)*100, 'ci_lb_pct': (lb_a-1)*100, 'ci_ub_pct': (ub_a-1)*100,
        'sig': lb_a>1.0, 'meets_target': (r_a-1)*100 >= KPI_LIFT_TARGET_PCT,
    },
    'cROAS_D7': {
        'label': 'D7 Revenue Lift\n(cROAS_D7)',
        'ratio': r_r, 'lb': lb_r, 'ub': ub_r,
        'lift_pct': (r_r-1)*100, 'ci_lb_pct': (lb_r-1)*100, 'ci_ub_pct': (ub_r-1)*100,
        'sig': lb_r>1.0, 'meets_target': (r_r-1)*100 >= KPI_LIFT_TARGET_PCT,
    },
}

print('=' * 64)
print(f'  INCREMENTALITY RESULTS — {CLIENT_NAME}  ({JIRA_TICKET})')
print(f'  {START_DATE} → {END_DATE} | {HOLDOUT_PCT:.0f}% Ghost-Bid | {n_bins} bins | Bootstrap')
print('=' * 64)
for key, v in results.items():
    sig = '✅' if v['sig'] else '⚠️ '
    tgt = f'🎯 Meets ≥{KPI_LIFT_TARGET_PCT:.0f}%' if v['meets_target'] else f'❌ Below {KPI_LIFT_TARGET_PCT:.0f}%'
    print(f"  {key:22s}: {v['lift_pct']:+7.1f}%  95% CI [{v['ci_lb_pct']:+6.1f}%, {v['ci_ub_pct']:+6.1f}%]  {sig}  {tgt}")

# %% [markdown]
# ## Section 3 — Interpretation & Forest Plot

# %%
v_i = results['CPD_INSTALL']

if v_i['sig'] and v_i['meets_target']:
    verdict = 'POSITIVE'; emoji = '✅'
    explanation = f"Moloco demonstrates statistically significant incremental impact ({v_i['lift_pct']:+.1f}% install lift), meeting the ≥{KPI_LIFT_TARGET_PCT:.0f}% target."
elif v_i['sig']:
    verdict = 'PARTIAL'; emoji = '⚠️'
    explanation = f"Moloco shows significant lift ({v_i['lift_pct']:+.1f}%), but below the {KPI_LIFT_TARGET_PCT:.0f}% target."
else:
    verdict = 'INCONCLUSIVE'; emoji = '❌'
    explanation = f"Lift estimate ({v_i['lift_pct']:+.1f}%) is not statistically significant at 95%."

print(f'{emoji} VERDICT: {verdict}'); print(explanation)

# %%
keys = ['CPD_INSTALL', 'CPD_DIST_ACT_D7', 'cROAS_D7']
fig, ax = plt.subplots(figsize=(11, 4))

for i, key in enumerate(keys):
    v = results[key]; lift=v['lift_pct']; lb=v['ci_lb_pct']; ub=v['ci_ub_pct']
    ax.barh(i, lift, height=0.45, color=MOLOCO_BLUE if v['sig'] else GRAY, alpha=0.85, zorder=3)
    ax.errorbar(lift, i, xerr=[[lift-lb],[ub-lift]], fmt='none', color='#222', capsize=5, lw=1.8, zorder=4)
    ax.text(max(ub,lift)+5, i, f'{lift:+.1f}%  [{lb:+.1f}%, {ub:+.1f}%]', va='center', fontsize=9)

ax.axvline(0, color='#555', lw=0.8, alpha=0.5)
ax.axvline(KPI_LIFT_TARGET_PCT, color='red', linestyle='--', alpha=0.7, label=f'Target ({KPI_LIFT_TARGET_PCT:.0f}%)')
ax.set_yticks(range(len(keys))); ax.set_yticklabels([results[k]['label'] for k in keys])
ax.set_xlabel('Incremental Lift (%, Bootstrap CPD ratio)')
ax.set_title(f'{CLIENT_NAME} — UA Incrementality Results\n{START_DATE} to {END_DATE}  |  {HOLDOUT_PCT:.0f}% Ghost-Bid',
             fontsize=13, fontweight='bold')
ax.legend(loc='lower right'); ax.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.savefig('forest_plot.png', dpi=150, bbox_inches='tight')
plt.show()
print('💾 forest_plot.png')

# %% [markdown]
# ## Section 4 — Daily Trend

# %%
q_daily = f"""
SELECT utc_date, exp_group_id,
       SUM(count_imp) AS impressions, SUM(count_install) AS installs,
       SUM(total_moloco_spent) AS spend_usd
FROM `explab-298609.summary_view.experiment_summary`
WHERE utc_date BETWEEN '{START_DATE}' AND '{END_DATE}'
  AND exp_group_id IN ({CONTROL_GROUP_ID}, {TEST_GROUP_ID})
GROUP BY 1, 2 ORDER BY 1, 2
"""
df_daily = run_query(q_daily, 'Daily metrics')
df_daily['installs_norm'] = df_daily.apply(
    lambda r: r['installs']/(CONTROL_SHARE if r['exp_group_id']==CONTROL_GROUP_ID else TEST_SHARE), axis=1)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 7), sharex=True)
for gid, lbl, color in [(CONTROL_GROUP_ID, f'Control (Ghost {HOLDOUT_PCT:.0f}%)', MOLOCO_ORANGE),
                         (TEST_GROUP_ID, f'Test (Normal {100-HOLDOUT_PCT:.0f}%)', MOLOCO_BLUE)]:
    d = df_daily[df_daily.exp_group_id==gid].sort_values('utc_date')
    ax1.plot(d.utc_date, d.installs_norm, marker='o', ms=4, label=lbl, color=color, lw=1.8)
ax1.set_ylabel('Installs (normalized)'); ax1.set_title('Daily Installs (Traffic-Normalized)')
ax1.legend(); ax1.grid(alpha=0.3)

td = df_daily[df_daily.exp_group_id==TEST_GROUP_ID].sort_values('utc_date')
ax2.bar(td.utc_date, td.spend_usd, color=MOLOCO_BLUE, alpha=0.7)
ax2.set_ylabel('Spend (USD)'); ax2.set_title('Test Group Daily Spend'); ax2.grid(alpha=0.3)
plt.xticks(rotation=30, ha='right'); plt.tight_layout()
plt.savefig('daily_trend.png', dpi=150, bbox_inches='tight'); plt.show()
print('💾 daily_trend.png')

# %% [markdown]
# ## Section 5 — Result Summary & Slide Generation

# %%
print('=' * 64)
print(f'  FINAL VERDICT: {emoji} {verdict}'); print(f'  {explanation}')
print('=' * 64)
display(pd.DataFrame([{
    'Metric': k, 'Lift': f"{v['lift_pct']:+.1f}%",
    '95% CI Lower': f"{v['ci_lb_pct']:+.1f}%", '95% CI Upper': f"{v['ci_ub_pct']:+.1f}%",
    'Significant?': '✅' if v['sig'] else '⚠️',
    f'≥{KPI_LIFT_TARGET_PCT:.0f}%?': '✅' if v['meets_target'] else '❌',
} for k, v in results.items()]))

# %%
# %pip install python-pptx --quiet

from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.dml.color import RGBColor
from pptx.enum.text import PP_ALIGN
import os
from datetime import date

C_BLUE  = RGBColor(0x1E,0x6F,0xFF); C_ORANGE= RGBColor(0xFF,0x6B,0x35)
C_DARK  = RGBColor(0x1A,0x1A,0x2E); C_WHITE = RGBColor(0xFF,0xFF,0xFF)
C_LIGHT = RGBColor(0xF5,0xF7,0xFF); C_GRAY  = RGBColor(0x8C,0x8C,0x8C)
C_GREEN = RGBColor(0x00,0xA8,0x5A); C_RED   = RGBColor(0xE5,0x3E,0x3E)
W,H = Inches(13.33),Inches(7.5)

prs = Presentation(); prs.slide_width,prs.slide_height = W,H

def add_rect(sl, l,t,w,h, fill=None, lc=None, lw=Pt(0)):
    sh = sl.shapes.add_shape(1,Inches(l),Inches(t),Inches(w),Inches(h))
    if fill: sh.fill.solid(); sh.fill.fore_color.rgb=fill
    else: sh.fill.background()
    sh.line.width=lw
    if lc: sh.line.color.rgb=lc
    else: sh.line.fill.background()

def add_txt(sl, text, l,t,w,h, sz=16, bold=False, color=C_DARK, align=PP_ALIGN.LEFT):
    tb = sl.shapes.add_textbox(Inches(l),Inches(t),Inches(w),Inches(h))
    tb.text_frame.word_wrap=True; p=tb.text_frame.paragraphs[0]; p.alignment=align
    r=p.add_run(); r.text=text; r.font.size=Pt(sz); r.font.bold=bold; r.font.color.rgb=color

def add_img(sl, path, l,t,w,h):
    if os.path.exists(path): sl.shapes.add_picture(path,Inches(l),Inches(t),Inches(w),Inches(h))

def blank(prs): return prs.slides.add_slide(prs.slide_layouts[6])
def footer(sl):
    add_rect(sl,0,7.2,13.33,0.3,fill=C_BLUE)
    add_txt(sl,'Moloco | Confidential',0.3,7.22,12,0.25,9,color=C_WHITE)

# S1: Title
s1=blank(prs); add_rect(s1,0,0,13.33,7.5,fill=C_DARK); add_rect(s1,0,0,0.35,7.5,fill=C_BLUE)
add_rect(s1,0.35,5.5,13,0.06,fill=C_BLUE)
add_txt(s1,'MOLOCO',0.7,0.5,12,0.6,11,bold=True,color=C_BLUE)
add_txt(s1,CLIENT_NAME,0.7,1.2,12,1.0,30,bold=True,color=C_WHITE)
add_txt(s1,'UA Incrementality Test — Results',0.7,2.2,12,0.7,22,color=C_WHITE)
add_txt(s1,f'Test period: {START_DATE} → {END_DATE}  |  {HOLDOUT_PCT:.0f}% Ghost-Bid  |  {PLATFORM}, {COUNTRY}',0.7,3.0,12,0.5,13,color=C_GRAY)
add_txt(s1,f'Prepared by Moloco KOR GDS  |  {date.today().strftime("%B %d, %Y")}',0.7,5.8,12,0.5,11,color=C_GRAY)

# S2: Test Design
s2=blank(prs); add_rect(s2,0,0,13.33,0.8,fill=C_DARK)
add_txt(s2,'Test Design',0.4,0.12,12,0.6,22,bold=True,color=C_WHITE)
for i,(k,v) in enumerate([('Test Type','Backend Ghost-Bid Incrementality (UPLIFT)'),
                            ('App',f'{APP_BUNDLE}  |  {PLATFORM}, {COUNTRY}'),
                            ('Campaign',f'{CAMPAIGN_NAME} ({CAMPAIGN_ID}) — Goal: {CAMPAIGN_GOAL}'),
                            ('Holdout',f'{HOLDOUT_PCT:.0f}% ghost-bid control  |  {100-HOLDOUT_PCT:.0f}% normal test'),
                            ('Duration',f'{START_DATE} → {END_DATE}'),
                            ('KPI Target',f'≥{KPI_LIFT_TARGET_PCT:.0f}% incremental conversion lift'),
                            ('ExpLab ID',EXPERIMENT_ID)]):
    y=1.0+i*0.79
    add_rect(s2,0.4,y,2.8,0.58,fill=C_BLUE); add_txt(s2,k,0.5,y+0.1,2.6,0.45,11,bold=True,color=C_WHITE)
    add_txt(s2,v,3.4,y+0.1,9.5,0.45,11,color=C_DARK)
footer(s2)

# S3: Key Results
s3=blank(prs); add_rect(s3,0,0,13.33,0.8,fill=C_DARK)
add_txt(s3,'Key Results',0.4,0.12,12,0.6,22,bold=True,color=C_WHITE)
for x, key in [(0.4,'CPD_INSTALL'),(4.7,'CPD_DIST_ACT_D7'),(9.0,'cROAS_D7')]:
    v=results[key]; lift=v['lift_pct']; lb=v['ci_lb_pct']; ub=v['ci_ub_pct']
    bc=C_BLUE if v['sig'] else RGBColor(0xBB,0xBB,0xBB)
    add_rect(s3,x,1.0,3.9,2.75,fill=C_LIGHT,lc=bc,lw=Pt(2))
    add_txt(s3,v['label'],x+0.1,1.1,3.7,0.5,10,bold=True,color=C_GRAY,align=PP_ALIGN.CENTER)
    add_txt(s3,f'{lift:+.1f}%',x+0.1,1.65,3.7,0.85,28,bold=True,color=C_DARK,align=PP_ALIGN.CENTER)
    add_txt(s3,f'95% CI: [{lb:+.1f}%, {ub:+.1f}%]',x+0.1,2.55,3.7,0.35,9,color=C_GRAY,align=PP_ALIGN.CENTER)
    badge='✅ Meets target' if v['meets_target'] else '❌ Below target'
    add_txt(s3,badge,x+0.1,2.92,3.7,0.35,9,bold=True,color=(C_GREEN if v['meets_target'] else C_RED),align=PP_ALIGN.CENTER)
    if not v['sig']: add_txt(s3,'⚠️ Not significant',x+0.1,3.27,3.7,0.3,8,color=C_ORANGE,align=PP_ALIGN.CENTER)
bc=C_GREEN if verdict=='POSITIVE' else (C_ORANGE if verdict=='PARTIAL' else C_RED)
add_rect(s3,0.4,4.1,12.5,0.8,fill=bc); add_txt(s3,f'{emoji}  {explanation}',0.6,4.2,12.2,0.6,12,bold=True,color=C_WHITE)
footer(s3)

# S4: Forest Plot
s4=blank(prs); add_rect(s4,0,0,13.33,0.8,fill=C_DARK)
add_txt(s4,'Statistical Confidence — 95% CI',0.4,0.12,12.5,0.6,22,bold=True,color=C_WHITE)
add_img(s4,'forest_plot.png',0.5,0.9,12.3,5.55)
add_txt(s4,'Bootstrap CPD ratio, 10k iterations. CI not crossing 0% = statistically significant at 95%.',0.5,6.6,12,0.4,9,color=C_GRAY)
footer(s4)

# S5: Daily Trend
s5=blank(prs); add_rect(s5,0,0,13.33,0.8,fill=C_DARK)
add_txt(s5,'Daily Performance During Test Period',0.4,0.12,12.5,0.6,22,bold=True,color=C_WHITE)
add_img(s5,'daily_trend.png',0.5,0.9,12.3,5.9); footer(s5)

# S6: Recommendations
s6=blank(prs); add_rect(s6,0,0,13.33,0.8,fill=C_DARK)
add_txt(s6,'Conclusion & Recommendations',0.4,0.12,12.5,0.6,22,bold=True,color=C_WHITE)
v_i=results['CPD_INSTALL']; v_a=results['CPD_DIST_ACT_D7']; v_r=results['cROAS_D7']
recs=[
    f'{emoji} {explanation}',
    f'D7 Action Lift: {v_a["lift_pct"]:+.1f}% | D7 Revenue Lift: {v_r["lift_pct"]:+.1f}%',
    '📈 Recommendation: ' + ('Scale UA budget — incrementality proven.' if verdict=="POSITIVE" else 'Review creative/bid strategy and re-test.'),
    '📅 Next: Share with client. Consider ROAS or D28 experiment after scaling.' if verdict=="POSITIVE" else '📅 Extend test to 4–6 weeks for more statistical power.',
]
for i,rec in enumerate(recs):
    y=1.0+i*1.35; add_rect(s6,0.5,y,12.3,1.1,fill=C_LIGHT,lc=C_BLUE,lw=Pt(1.5))
    add_txt(s6,rec,0.7,y+0.2,11.8,0.75,12,color=C_DARK)
footer(s6)

pptx = f'{JIRA_TICKET}_{CLIENT_NAME.replace(" ","_")}_Incrementality_Results.pptx'
prs.save(pptx)
print(f'💾 {pptx} — 6 slides generated')
