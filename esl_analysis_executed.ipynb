# %% [markdown]
# # ESL Learning Analysis — ChatGPT Proofreading History
#
# | Field | Value |
# |-------|-------|
# | **Author** | Haewon |
# | **Last update** | 2026-03-22 |
# | **Objective** | Extract English learning insights from ChatGPT proofreading history |
# | **Sections** | 1. Parse pairs · 2. Pattern analysis · 3. Before/after diff · 4. Anki export |

# %% [markdown]
# ## 0 — Setup & Load

# %%
import json
import re
import glob
import difflib
import os
import csv
from datetime import datetime
from collections import defaultdict, Counter

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.dpi'] = 130

CONV_DIR = "/tmp/chatgpt_extract"
OUT_DIR  = "/Users/haewon.yum/Documents/ESL"

PROOFREAD_KEYWORDS = [
    "proofread", "proof read", "grammar", "correct my", "fix my", "check my",
    "rewrite", "rephrase", "improve my", "edit this", "revise", "natural english",
    "sound natural", "native speaker", "more professional", "better way to say",
    "is this correct", "does this sound", "awkward", "more fluent",
    "교정", "영어", "문법", "수정",
]

# %%
def get_messages(conversation):
    mapping = conversation.get("mapping", {})
    current = conversation.get("current_node")
    chain, visited = [], set()
    node_id = current
    while node_id and node_id not in visited:
        visited.add(node_id)
        node = mapping.get(node_id, {})
        msg = node.get("message")
        if msg:
            chain.append(msg)
        node_id = node.get("parent")
    chain.reverse()
    return chain

def get_text(message):
    content = message.get("content", {}) or {}
    parts = content.get("parts", [])
    texts = []
    for p in parts:
        if isinstance(p, str):
            texts.append(p)
        elif isinstance(p, dict):
            texts.append(p.get("text") or p.get("content") or "")
    return "\n".join(texts).strip()

def is_proofread(text):
    tl = text.lower()
    return any(kw in tl for kw in PROOFREAD_KEYWORDS)

def fmt_date(ts):
    try:
        return datetime.fromtimestamp(float(ts)).strftime("%Y-%m-%d")
    except:
        return "unknown"

def load_pairs():
    pairs = []
    files = sorted(glob.glob(f"{CONV_DIR}/conversations-*.json"))
    for fpath in files:
        with open(fpath) as f:
            convs = json.load(f)
        for conv in convs:
            msgs = get_messages(conv)
            for i, msg in enumerate(msgs):
                if msg.get("author", {}).get("role") != "user":
                    continue
                user_text = get_text(msg)
                if not user_text or not is_proofread(user_text):
                    continue
                for j in range(i+1, len(msgs)):
                    nm = msgs[j]
                    if nm.get("author", {}).get("role") == "assistant":
                        asst = get_text(nm)
                        if asst:
                            pairs.append({
                                "conv_id":   conv.get("id", ""),
                                "title":     conv.get("title", ""),
                                "date":      fmt_date(msg.get("create_time")),
                                "user":      user_text,
                                "assistant": asst,
                            })
                        break
    return pairs

pairs = load_pairs()
df = pd.DataFrame(pairs)
print(f"Loaded {len(df)} proofreading pairs")
df.head(3)
# Out:
# Loaded 2453 proofreading pairs
#                                 conv_id  \
# 0  00005087-b793-4361-9671-4a518f345b8a
# 1  006504e7-e5c3-46a1-8657-4ab39ec9405f
# 2  047ac4b8-918a-4026-b809-634fe3c020cf
#
#                                      title        date  \
# 0                          DateTime 타입 변환.  2023-07-12
# 1  Developed Parts Demand Prediction Model  2023-11-17
# 2               Considering Netmarble Sync  2024-07-15
#
#                                                 user  \
# 0  위의 초기화 예시에서, createdAt말고, lastUpdatedAt도 _pars...
# 1  아래 resume에 들어갈 문장을 영어로 번역해줘. \n\n자동차 부품 수리 이력 ...
# 2  Proofread: @hedan.zeng@moloco.com Hi hedan, We...
#
#                                            assistant
# 0  맞습니다. `createdAt` 외에도 `lastUpdatedAt`도 `_parse...
# 1  For your resume, the translated sentence would...
# 2  Sure, here is the proofread version:\n\n---\n\...

# %% [markdown]
# ## 1 — Extract Corrected Text from Assistant Response
#
# ChatGPT typically puts the corrected version in a fenced block or after a separator. We extract it here.

# %%
def extract_corrected(assistant_text):
    """
    Try to extract just the corrected text from ChatGPT's response.
    Handles common patterns:
      - Text inside --- separators
      - Triple-backtick code blocks
      - Blockquotes (> lines)
      - After intro phrases like 'Here's the corrected version:'
    Returns the best candidate, or the full response if no pattern matches.
    """
    text = assistant_text.strip()

    # Pattern 1: between --- separators (most common ChatGPT format)
    sep_matches = re.findall(r'---+\s*\n(.*?)\n\s*---+', text, re.DOTALL)
    if sep_matches:
        return max(sep_matches, key=len).strip()

    # Pattern 2: triple backtick block
    code_matches = re.findall(r'```(?:\w*)\n(.*?)```', text, re.DOTALL)
    if code_matches:
        return max(code_matches, key=len).strip()

    # Pattern 3: blockquotes
    bq_lines = [l.lstrip('> ') for l in text.split('\n') if l.startswith('>')]
    if len(bq_lines) >= 2:
        return '\n'.join(bq_lines).strip()

    # Pattern 4: after intro phrase
    intro = re.search(
        r'(?:here(?:\'s| is) (?:the )?(?:corrected|revised|improved|proofread|rewritten)[^:\n]*:?|'
        r'corrected version:?|revised version:?)\s*\n+',
        text, re.IGNORECASE
    )
    if intro:
        after = text[intro.end():].strip()
        # Take until next heading-like line or double newline
        chunk = re.split(r'\n{3,}|\n(?:#{1,3} |\*\*[A-Z])', after)[0]
        if len(chunk) > 30:
            return chunk.strip()

    return ""  # couldn't extract cleanly


def extract_user_draft(user_text):
    """
    Strip the proofreading instruction from the user's message to get just the draft.
    e.g. 'proofread:\n\nHi team...' -> 'Hi team...'
    """
    # Remove leading instruction line(s)
    cleaned = re.sub(
        r'^(?:proofread|please proofread|can you proofread|fix|correct|revise|improve|rewrite|check)[^\n]*\n+',
        '', user_text.strip(), flags=re.IGNORECASE
    )
    return cleaned.strip()


df['draft']     = df['user'].apply(extract_user_draft)
df['corrected'] = df['assistant'].apply(extract_corrected)

# How many had clean extractions?
extracted = df[df['corrected'].str.len() > 20]
print(f"Clean corrected text extracted: {len(extracted)} / {len(df)} ({100*len(extracted)//len(df)}%)")
extracted[['date','title','draft','corrected']].head(3)
# Out:
# Clean corrected text extracted: 1481 / 2453 (60%)
#          date                       title  \
# 0  2023-07-12             DateTime 타입 변환.
# 2  2024-07-15  Considering Netmarble Sync
# 7  2024-05-13    Reschedule Update Needed
#
#                                                draft  \
# 0  위의 초기화 예시에서, createdAt말고, lastUpdatedAt도 _pars...
# 2  Proofread: @hedan.zeng@moloco.com Hi hedan, We...
# 7  Hi Ashank, \n\nHope you are doing well. \n\nI ...
#
#                                            corrected
# 0  class ChildModel {\n  // ...\n\n  ChildModel({...
# 2  @hedan.zeng@moloco.com\n\nHi Hedan,\n\nWe (GDS...
# 7  Hi Ashank,\n\nI hope you are doing well.\n\nI ...

# %% [markdown]
# ## 2 — Before / After Diff
#
# Compare draft vs corrected word-by-word and display highlighted diffs.

# %%
from IPython.display import HTML, display

def word_diff_html(original, corrected):
    """Return HTML showing word-level diff (red=removed, green=added)."""
    orig_words = original.split()
    corr_words = corrected.split()
    matcher = difflib.SequenceMatcher(None, orig_words, corr_words)
    html = []
    for op, i1, i2, j1, j2 in matcher.get_opcodes():
        if op == 'equal':
            html.append(' '.join(orig_words[i1:i2]))
        elif op == 'replace':
            html.append(f'<span style="background:#fdd;text-decoration:line-through;color:#900">{" ".join(orig_words[i1:i2])}</span>')
            html.append(f'<span style="background:#dfd;color:#060">{" ".join(corr_words[j1:j2])}</span>')
        elif op == 'delete':
            html.append(f'<span style="background:#fdd;text-decoration:line-through;color:#900">{" ".join(orig_words[i1:i2])}</span>')
        elif op == 'insert':
            html.append(f'<span style="background:#dfd;color:#060">{" ".join(corr_words[j1:j2])}</span>')
    return ' '.join(html)


def show_diffs(n=10, min_len=50):
    """Display n random proofreading diffs that have clean extractions."""
    sample = extracted[extracted['draft'].str.len() >= min_len].sample(n=min(n, len(extracted)), random_state=42)
    for _, row in sample.iterrows():
        diff_html = word_diff_html(row['draft'][:800], row['corrected'][:800])
        display(HTML(f"""
        <div style="border:1px solid #ccc;border-radius:6px;padding:12px;margin:8px 0;font-family:sans-serif">
          <div style="font-size:11px;color:#888;margin-bottom:6px">{row['date']} | {row['title'][:60]}</div>
          <div style="line-height:1.7;font-size:14px">{diff_html}</div>
        </div>
        """))

show_diffs(n=10)
# Out:
#         <div style="border:1px solid #ccc;border-radius:6px;padding:12px;margin:8px 0;font-family:sans-serif">
#           <div style="font-size:11px;color:#888;margin-bottom:6px">2024-09-20 | AWS Regulatory Policy CV Help</div>
#           <div style="line-height:1.7;font-size:14px"><span style="background:#fdd;text-decoration:line-through;color:#900">Seoul</span> <span style="background:#dfd;color:#060">**Seoul</span> National University, Seoul, <span style="background:#fdd;text-decoration:line-through;color:#900">Korea Ph.D. candidate,</span> <span style="background:#dfd;color:#060">Korea** **Ph.D. Candidate,</span> School of <span style="background:#fdd;text-decoration:line-through;color:#900">Law</span> <span style="background:#dfd;color:#060">Law** |</span> Mar 2014 - Aug 2019 <span style="background:#dfd;color:#060">-</span> Research <span style="background:#fdd;text-decoration:line-through;color:#900">focuses</span> <span style="background:#dfd;color:#060">focused</span> on the <span style="background:#fdd;text-decoration:line-through;color:#900">(de-)regulation on</span> <span style="background:#dfd;color:#060">regulation and deregulation of</span> innovative industries. Also keenly interested in <span style="background:#fdd;text-decoration:line-through;color:#900">exterritorial</span> <span style="background:#dfd;color:#060">the extraterritorial</span> application of tech regulations.</div>
#         </div>
#         <div style="border:1px solid #ccc;border-radius:6px;padding:12px;margin:8px 0;font-family:sans-serif">
#           <div style="font-size:11px;color:#888;margin-bottom:6px">2025-12-04 | Proofreading assistance</div>
#           <div style="line-height:1.7;font-size:14px">Sharing this <span style="background:#fdd;text-decoration:line-through;color:#900">as</span> <span style="background:#dfd;color:#060">for</span> your reference: <span style="background:#fdd;text-decoration:line-through;color:#900">It could</span> <span style="background:#dfd;color:#060">This might</span> be <span style="background:#fdd;text-decoration:line-through;color:#900">the</span> <span style="background:#dfd;color:#060">an</span> edge case, but <span style="background:#fdd;text-decoration:line-through;color:#900">in case of</span> <span style="background:#dfd;color:#060">when an **attributed postback is</span> not <span style="background:#fdd;text-decoration:line-through;color:#900">receiving attributed postback regardless of having</span> <span style="background:#dfd;color:#060">received**—even though</span> unattributed <span style="background:#fdd;text-decoration:line-through;color:#900">data, RE</span> <span style="background:#dfd;color:#060">data is available—the **RE</span> App Landing/Action/ROAS <span style="background:#fdd;text-decoration:line-through;color:#900">campaign would</span> <span style="background:#dfd;color:#060">campaign** may</span> not <span style="background:#fdd;text-decoration:line-through;color:#900">working</span> <span style="background:#dfd;color:#060">function</span> as expected, since <span style="background:#dfd;color:#060">the</span> RE model predicts directly from the <span style="background:#fdd;text-decoration:line-through;color:#900">impression (instead of</span> <span style="background:#dfd;color:#060">**impression** (rather than the</span> install). <span style="background:#fdd;text-decoration:line-through;color:#900">FYI, for RE</span> <span style="background:#dfd;color:#060">For your information, in the **RE</span> App <span style="background:#fdd;text-decoration:line-through;color:#900">Landing,</span> <span style="background:#dfd;color:#060">Landing** setup,</span> any events <span style="background:#dfd;color:#060">occurring</span> within <span style="background:#fdd;text-decoration:line-through;color:#900">2</span> <span style="background:#dfd;color:#060">**2</span> hours after <span style="background:#fdd;text-decoration:line-through;color:#900">impression</span> <span style="background:#dfd;color:#060">an impression**</span> are labeled as positive. <span style="background:#fdd;text-decoration:line-through;color:#900">Currently there's a case that we're</span> <span style="background:#dfd;color:#060">In the current case, we are</span> receiving <span style="background:#fdd;text-decoration:line-through;color:#900">unattributed postback,</span> <span style="background:#dfd;color:#060">**unattributed postbacks**</span> but not <span style="background:#fdd;text-decoration:line-through;color:#900">attributed one perhaps because of misconfiguration</span> <span style="background:#dfd;color:#060">**attributed ones**, possibly due to a **misconfiguration</span> with <span style="background:#fdd;text-decoration:line-through;color:#900">MMP</span> <span style="background:#dfd;color:#060">the MMP**</span> for <span style="background:#dfd;color:#060">an</span> agency running campaigns for the same app bundle <span style="background:#fdd;text-decoration:line-through;color:#900">run by</span> <span style="background:#dfd;color:#060">as</span> the direct customer <span style="background:#fdd;text-decoration:line-through;color:#900">(WIP</span> <span style="background:#dfd;color:#060">(we are in the process</span> of <span style="background:#fdd;text-decoration:line-through;color:#900">checking from</span> <span style="background:#dfd;color:#060">verifying this with</span> the <span style="background:#fdd;text-decoration:line-through;color:#900">customer end). And we're</span> <span style="background:#dfd;color:#060">customer). As a result, we are</span> observing <span style="background:#fdd;text-decoration:line-through;color:#900">s ...
#         </div>
#         <div style="border:1px solid #ccc;border-radius:6px;padding:12px;margin:8px 0;font-family:sans-serif">
#           <div style="font-size:11px;color:#888;margin-bottom:6px">2025-07-03 | Ladder vs Summarizing Statement</div>
#           <div style="line-height:1.7;font-size:14px">Running a CPA campaign optimized <span style="background:#fdd;text-decoration:line-through;color:#900">towards</span> <span style="background:#dfd;color:#060">for</span> the custom event <span style="background:#fdd;text-decoration:line-through;color:#900">“‘af_level_9’”</span> <span style="background:#dfd;color:#060">**"af_level_9"**</span> can <span style="background:#fdd;text-decoration:line-through;color:#900">deliver</span> <span style="background:#dfd;color:#060">lead to</span> better campaign performance in terms of retention compared to a D7 ROAS campaign using <span style="background:#fdd;text-decoration:line-through;color:#900">“af_purchase”.</span> <span style="background:#dfd;color:#060">**"af_purchase"**.</span> Based on <span style="background:#fdd;text-decoration:line-through;color:#900">the</span> previous analysis, <span style="background:#fdd;text-decoration:line-through;color:#900">‘af_level_9’ events</span> <span style="background:#dfd;color:#060">**"af_level_9"**</span> is the <span style="background:#dfd;color:#060">event</span> most <span style="background:#dfd;color:#060">strongly</span> correlated with <span style="background:#fdd;text-decoration:line-through;color:#900">dX retention</span> <span style="background:#dfd;color:#060">**dX retention**</span> among all <span style="background:#fdd;text-decoration:line-through;color:#900">the</span> <span style="background:#dfd;color:#060">tracked</span> events.</div>
#         </div>
#         <div style="border:1px solid #ccc;border-radius:6px;padding:12px;margin:8px 0;font-family:sans-serif">
#           <div style="font-size:11px;color:#888;margin-bottom:6px">2024-11-04 | Hiring Manager Interview Intro</div>
#           <div style="line-height:1.7;font-size:14px"><span style="background:#fdd;text-decoration:line-through;color:#900">proofread: [Q]</span> <span style="background:#dfd;color:#060">**Question:**</span> It seems that you developed models for the project <span style="background:#fdd;text-decoration:line-through;color:#900">we</span> mentioned in your CV. However, to be <span style="background:#fdd;text-decoration:line-through;color:#900">honest</span> <span style="background:#dfd;color:#060">honest,</span> building ML models is not <span style="background:#fdd;text-decoration:line-through;color:#900">in</span> <span style="background:#dfd;color:#060">within the scope of</span> our <span style="background:#fdd;text-decoration:line-through;color:#900">work scope.</span> <span style="background:#dfd;color:#060">work.</span> What <span style="background:#fdd;text-decoration:line-through;color:#900">do you think about this aspect?</span> <span style="background:#dfd;color:#060">are your thoughts on this?</span></div>
#         </div>
#         <div style="border:1px solid #ccc;border-radius:6px;padding:12px;margin:8px 0;font-family:sans-serif">
#           <div style="font-size:11px;color:#888;margin-bottom:6px">2025-10-13 | Korean translation birthday message</div>
#           <div style="line-height:1.7;font-size:14px"><span style="background:#fdd;text-decoration:line-through;color:#900">This</span> <span style="background:#dfd;color:#060">**This</span> is from <span style="background:#fdd;text-decoration:line-through;color:#900">the</span> countries <span style="background:#fdd;text-decoration:line-through;color:#900">they're NOT</span> <span style="background:#dfd;color:#060">where they’re *not*</span> currently running campaigns with Moloco. 하지만 unattributed <span style="background:#fdd;text-decoration:line-through;color:#900">install은</span> <span style="background:#dfd;color:#060">installs가</span> 발생하고 있는 <span style="background:#fdd;text-decoration:line-through;color:#900">국가이므로</span> <span style="background:#dfd;color:#060">국가들이기 때문에,</span> 고객 <span style="background:#fdd;text-decoration:line-through;color:#900">관점에서는 그들이 고려하는</span> <span style="background:#dfd;color:#060">입장에서는 고려 대상</span> 국가 <span style="background:#fdd;text-decoration:line-through;color:#900">리스트가 될 수</span> <span style="background:#dfd;color:#060">리스트로 볼 수도</span> 있다고 <span style="background:#fdd;text-decoration:line-through;color:#900">생각해요.</span> <span style="background:#dfd;color:#060">생각해요.**</span></div>
#         </div>
#         <div style="border:1px solid #ccc;border-radius:6px;padding:12px;margin:8px 0;font-family:sans-serif">
#           <div style="font-size:11px;color:#888;margin-bottom:6px">2024-10-23 | K-ID Opportunity Inquiry</div>
#           <div style="line-height:1.7;font-size:14px"><span style="background:#fdd;text-decoration:line-through;color:#900">Proofread:</span> Yes, I was looking for an opportunity where the team and I could work together for the long haul. It might <span style="background:#dfd;color:#060">not</span> be <span style="background:#fdd;text-decoration:line-through;color:#900">not</span> easy to have a strong sense of belonging if <span style="background:#fdd;text-decoration:line-through;color:#900">I work</span> <span style="background:#dfd;color:#060">I’m working</span> remotely with a short-term <span style="background:#fdd;text-decoration:line-through;color:#900">period of</span> contract.</div>
#         </div>
#         <div style="border:1px solid #ccc;border-radius:6px;padding:12px;margin:8px 0;font-family:sans-serif">
#           <div style="font-size:11px;color:#888;margin-bottom:6px">2026-01-18 | Sentence Meaning Explanation</div>
#           <div style="line-height:1.7;font-size:14px"><span style="background:#fdd;text-decoration:line-through;color:#900">proofread: Hi team,</span> <span style="background:#dfd;color:#060">**Hi team,**</span> I'm currently investigating the recent CPI spike. Could you <span style="background:#fdd;text-decoration:line-through;color:#900">review this</span> <span style="background:#dfd;color:#060">take a look</span> and <span style="background:#fdd;text-decoration:line-through;color:#900">give</span> <span style="background:#dfd;color:#060">share any</span> feedback? In particular, I'd <span style="background:#fdd;text-decoration:line-through;color:#900">love</span> <span style="background:#dfd;color:#060">appreciate</span> your thoughts on <span style="background:#fdd;text-decoration:line-through;color:#900">what the</span> <span style="background:#dfd;color:#060">potential</span> next <span style="background:#fdd;text-decoration:line-through;color:#900">steps should be.</span> <span style="background:#dfd;color:#060">steps.</span> Any suggestions are <span style="background:#fdd;text-decoration:line-through;color:#900">welcomed.</span> <span style="background:#dfd;color:#060">welcome —</span> thank you!</div>
#         </div>
#         <div style="border:1px solid #ccc;border-radius:6px;padding:12px;margin:8px 0;font-family:sans-serif">
#           <div style="font-size:11px;color:#888;margin-bottom:6px">2025-06-04 | 4월 실적 번역 및 요약</div>
#           <div style="line-height:1.7;font-size:14px"><span style="background:#fdd;text-decoration:line-through;color:#900">@Cyan</span> <span style="background:#dfd;color:#060">**@Cyan**</span> Regarding <span style="background:#dfd;color:#060">the</span> CPI adjuster, creating <span style="background:#dfd;color:#060">a</span> PR is <span style="background:#fdd;text-decoration:line-through;color:#900">pretty</span> <span style="background:#dfd;color:#060">fairly</span> simple and <span style="background:#fdd;text-decoration:line-through;color:#900">straightforward, ( we</span> <span style="background:#dfd;color:#060">straightforward—we</span> have a clear guide for <span style="background:#dfd;color:#060">the</span> econfig <span style="background:#fdd;text-decoration:line-through;color:#900">setup), so</span> <span style="background:#dfd;color:#060">setup.</span> I believe <span style="background:#dfd;color:#060">the</span> DA <span style="background:#dfd;color:#060">team</span> can support <span style="background:#fdd;text-decoration:line-through;color:#900">this.</span> <span style="background:#dfd;color:#060">this, while the</span> GDS regional POC can still <span style="background:#fdd;text-decoration:line-through;color:#900">be</span> <span style="background:#dfd;color:#060">serve as</span> reviewers.</div>
#         </div>
#         <div style="border:1px solid #ccc;border-radius:6px;padding:12px;margin:8px 0;font-family:sans-serif">
#           <div style="font-size:11px;color:#888;margin-bottom:6px">2025-04-16 | 팀 리소스 제한 안내</div>
#           <div style="line-height:1.7;font-size:14px">All UA tests <span style="background:#fdd;text-decoration:line-through;color:#900">proved</span> <span style="background:#dfd;color:#060">demonstrated</span> Moloco’s install incrementality with statistical <span style="background:#fdd;text-decoration:line-through;color:#900">significance</span> <span style="background:#dfd;color:#060">significance.</span> 6 out of 8 tests showed efficiency greater than <span style="background:#fdd;text-decoration:line-through;color:#900">100%</span> <span style="background:#dfd;color:#060">100%.</span></div>
#         </div>
#         <div style="border:1px solid #ccc;border-radius:6px;padding:12px;margin:8px 0;font-family:sans-serif">
#           <div style="font-size:11px;color:#888;margin-bottom:6px">2025-04-07 | Proofreading and Clarification</div>
#           <div style="line-height:1.7;font-size:14px">Hi @lei.cao, <span style="background:#fdd;text-decoration:line-through;color:#900">the</span> <span style="background:#dfd;color:#060">The</span> customer wanted to confirm <span style="background:#fdd;text-decoration:line-through;color:#900">that anyway</span> <span style="background:#dfd;color:#060">whether</span> they need to use GCS to store <span style="background:#dfd;color:#060">the</span> user list data and send us <span style="background:#fdd;text-decoration:line-through;color:#900">‘data_file_path’(gcs</span> <span style="background:#dfd;color:#060">the `data_file_path` (GCS</span> path) via <span style="background:#fdd;text-decoration:line-through;color:#900">customer</span> <span style="background:#dfd;color:#060">the [customer</span> creation <span style="background:#fdd;text-decoration:line-through;color:#900">[api](https://www.notion.so/Netmarble-CustomerSet-Creating-API-communication-1cec72567e2480fca351eda3cb525bc3?pvs=21).</span> <span style="background:#dfd;color:#060">API](https://www.notion.so/Netmarble-CustomerSet-Creating-API-communication-1cec72567e2480fca351eda3cb525bc3?pvs=21).</span> My understanding is <span style="background:#fdd;text-decoration:line-through;color:#900">‘correct’. right?</span> <span style="background:#dfd;color:#060">that this is correct—could you please confirm?</span> In that case, does the customer need to have their own <span style="background:#fdd;text-decoration:line-through;color:#900">GCS?</span> <span style="background:#dfd;color:#060">GCS,</span> or <span style="background:#fdd;text-decoration:line-through;color:#900">Can</span> <span style="background:#dfd;color:#060">can</span> we provide <span style="background:#fdd;text-decoration:line-through;color:#900">GCS? (기술적으로도 말이 되는지 알려줘.)</span> <span style="background:#dfd;color:#060">one? (Also, could you let me know if this makes sense technically as well?)</span></div>
#         </div>

# %% [markdown]
# ## 3 — Pattern Analysis: What Types of Errors Do You Make?
#
# Classify each word-level change into an error category.

# %%
ARTICLES    = {'a', 'an', 'the'}
PREPOSITIONS = {'in', 'on', 'at', 'for', 'with', 'to', 'of', 'from', 'by', 'about',
                'into', 'through', 'during', 'before', 'after', 'above', 'below',
                'between', 'among', 'under', 'over', 'along', 'around', 'since', 'until'}
CONJUNCTIONS = {'and', 'but', 'or', 'so', 'yet', 'for', 'nor', 'although', 'because',
                'since', 'while', 'whereas', 'however', 'therefore', 'thus'}
PRONOUNS    = {'i', 'me', 'my', 'we', 'us', 'our', 'you', 'your', 'he', 'she', 'it',
               'they', 'them', 'their', 'this', 'that', 'these', 'those'}
BE_VERBS    = {'is', 'are', 'was', 'were', 'be', 'been', 'being', 'am'}

def categorize_change(removed_words, added_words):
    """Assign a category to a single diff chunk."""
    rem = [w.lower().strip('.,;:!?\'"') for w in removed_words]
    add = [w.lower().strip('.,;:!?\'"') for w in added_words]
    rem_set, add_set = set(rem), set(add)

    # Article: added/removed/swapped
    if rem_set <= ARTICLES or add_set <= ARTICLES:
        return 'Article (a/an/the)'
    if rem_set & ARTICLES or add_set & ARTICLES:
        return 'Article (a/an/the)'

    # Preposition
    if (rem_set | add_set) & PREPOSITIONS and len(rem) <= 2 and len(add) <= 2:
        return 'Preposition'

    # Verb tense / form (simple heuristic)
    rem_str, add_str = ' '.join(rem), ' '.join(add)
    if re.search(r'\b(ed|ing|s)\b', rem_str) or re.search(r'\b(ed|ing|s)\b', add_str):
        if len(rem) == 1 and len(add) == 1:
            return 'Verb tense / form'

    # Be verb
    if rem_set <= BE_VERBS or add_set <= BE_VERBS:
        return 'Be verb (is/are/was)'

    # Word order (same words, different order)
    if sorted(rem) == sorted(add) and rem != add:
        return 'Word order'

    # Redundancy removal
    if not rem and add:
        return 'Missing word (insertion)'
    if rem and not add:
        return 'Redundant word (deletion)'

    # Capitalization
    if [w.lower() for w in removed_words] == [w.lower() for w in added_words]:
        return 'Capitalization'

    # Conjunction / transition
    if (rem_set | add_set) & CONJUNCTIONS and len(rem) <= 2:
        return 'Conjunction / connector'

    # Plural / singular
    if len(rem) == 1 and len(add) == 1:
        r, a = rem[0], add[0]
        if (r+'s' == a) or (a+'s' == r) or (r[:-1] == a) or (a[:-1] == r):
            return 'Singular / plural'

    # Default
    return 'Word choice / phrasing'


def analyze_patterns(df_in, max_rows=500):
    """Run diff on all pairs and return change records."""
    changes = []
    sample = df_in.head(max_rows)
    for _, row in sample.iterrows():
        orig = row['draft'][:600].split()
        corr = row['corrected'][:600].split()
        if not orig or not corr:
            continue
        matcher = difflib.SequenceMatcher(None, orig, corr, autojunk=False)
        for op, i1, i2, j1, j2 in matcher.get_opcodes():
            if op == 'equal':
                continue
            rem = orig[i1:i2]
            add = corr[j1:j2]
            cat = categorize_change(rem, add)
            changes.append({
                'date':     row['date'],
                'category': cat,
                'removed':  ' '.join(rem),
                'added':    ' '.join(add),
                'context':  ' '.join(orig[max(0,i1-3):i2+3]),
            })
    return pd.DataFrame(changes)

print("Analyzing patterns (may take ~30s)...")
changes_df = analyze_patterns(extracted)
print(f"Total changes analyzed: {len(changes_df)}")
changes_df.head()
# Out:
# Analyzing patterns (may take ~30s)...
# Total changes analyzed: 3319
#          date                category  \
# 0  2023-07-12  Word choice / phrasing
# 1  2024-07-15      Article (a/an/the)
# 2  2024-07-15          Capitalization
# 3  2024-07-15      Article (a/an/the)
# 4  2024-07-15      Article (a/an/the)
#
#                                              removed  \
# 0  위의 초기화 예시에서, createdAt말고, lastUpdatedAt도 _pars...
# 1                                         Proofread:
# 2                                             hedan,
# 3
# 4
#
#                                                added  \
# 0  class ChildModel { // ... ChildModel({ // ... ...
# 1
# 2                                             Hedan,
# 3                                                the
# 4                                               open
#
#                                              context
# 0  위의 초기화 예시에서, createdAt말고, lastUpdatedAt도 _pars...
# 1        Proofread: @hedan.zeng@moloco.com Hi hedan,
# 2  Proofread: @hedan.zeng@moloco.com Hi hedan, We...
# 3                          a sync with Sales team to
# 4                       also check how they are open

# %%
# --- Plot: error category frequency ---
cat_counts = changes_df['category'].value_counts()

fig, ax = plt.subplots(figsize=(9, 5))
bars = ax.barh(cat_counts.index[::-1], cat_counts.values[::-1], color='steelblue')
ax.bar_label(bars, padding=3, fontsize=10)
ax.set_xlabel('Number of corrections')
ax.set_title('Your Most Frequent English Correction Types', fontsize=13, pad=12)
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, 'error_categories.png'), dpi=150, bbox_inches='tight')
plt.show()

print("\nTop categories:")
print(cat_counts.to_string())
# Out:
# Top categories:
# category
# Word choice / phrasing     1511
# Article (a/an/the)         1320
# Preposition                 189
# Conjunction / connector     112
# Capitalization               75
# Singular / plural            72
# Be verb (is/are/was)         27
# Verb tense / form            13

# %%
# --- Plot: error trend over time ---
changes_df['year_month'] = pd.to_datetime(changes_df['date'], errors='coerce').dt.to_period('M')
trend = (
    changes_df.dropna(subset=['year_month'])
    .groupby(['year_month','category'])
    .size()
    .unstack(fill_value=0)
)

top_cats = cat_counts.head(5).index
trend_top = trend[top_cats] if set(top_cats) <= set(trend.columns) else trend

fig, ax = plt.subplots(figsize=(12, 5))
trend_top.plot(ax=ax, marker='o', markersize=3, linewidth=1.5)
ax.set_xlabel('Month')
ax.set_ylabel('Correction count')
ax.set_title('Error Trends Over Time (Top 5 Categories)', fontsize=13)
ax.legend(loc='upper left', fontsize=9)
ax.spines[['top','right']].set_visible(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, 'error_trend.png'), dpi=150, bbox_inches='tight')
plt.show()

# %%
# --- Top specific corrections per category ---
print("=== Most frequent specific corrections ===\n")
for cat in cat_counts.head(6).index:
    sub = changes_df[changes_df['category'] == cat].copy()
    sub['pair'] = sub['removed'].str[:30] + ' → ' + sub['added'].str[:30]
    top = sub['pair'].value_counts().head(8)
    print(f"\n[{cat}]")
    for pair, cnt in top.items():
        print(f"  {cnt:3d}x  {pair}")
# Out:
# === Most frequent specific corrections ===
#
#
# [Word choice / phrasing]
#     8x  Haewon: → "Haewon:
#     6x  I'm → I’m
#     6x  can → could
#     5x  Best, → Best regards,
#     5x  KOR → Korea
#     5x  I'm → I am
#     4x  want → would like
#     4x  I’ve → I
#
# [Article (a/an/the)]
#    88x   → the
#    39x   → a
#    25x  proofread: →
#    20x  the →
#    10x  Proofread: →
#     8x   → an
#     8x  the → a
#     7x   → -
#
# [Preposition]
#     4x  for → in
#     4x  for → on
#     3x  to → with
#     3x  of → for
#     3x  on → in
#     3x  in → on
#     3x  from → in
#     2x  after → following
#
# [Conjunction / connector]
#     3x  Have → and have
#     2x  but → However,
#     2x  / → and
#     1x  spending. → spending for both Q1 and Q2.
#     1x  yet → it
#     1x  change / → change, and determine
#     1x  impressive, → clear, candid, and transparent
#     1x  finally make → and ultimately making
#
# [Capitalization]
#     4x  (High → (high
#     3x  thank → Thank
#     2x  'pump → 'Pump
#     2x  referring → Referring
#     2x  and → AND
#     2x  team, → Team,
#     2x  please → Please
#     2x  when → When
#
# [Singular / plural]
#     3x  result → results
#     2x  system → systems
#     2x  market. → markets.
#     2x  request → requests
#     2x  Jul → July
#     1x  advertiser → advertisers
#     1x  regulation, → regulations,
#     1x  competitors’ → competitors'

# %% [markdown]
# ## 4 — Anki Flashcard Export
#
# Exports two CSV files:
# - `anki_corrections.csv` — Before/After pairs (one per correction)
# - `anki_patterns.csv` — Error category cards with example sentences
#
# **How to import into Anki:**
# 1. Open Anki → File → Import
# 2. Select the CSV file
# 3. Set field separator to comma
# 4. Map: Field 1 = Front, Field 2 = Back, Field 3 = Tags

# %%
# --- Anki Card 1: Before/After pairs (from clean diffs) ---

def make_anki_pair_cards(changes_df, max_cards=500):
    """Create cards: Front=original phrase, Back=corrected phrase + category."""
    cards = []
    # Filter to meaningful changes (not too short, not too long)
    filtered = changes_df[
        (changes_df['removed'].str.len() > 2) &
        (changes_df['added'].str.len() > 2) &
        (changes_df['removed'] != '') &
        (changes_df['added'] != '')
    ].copy()

    # Deduplicate same corrections
    filtered['key'] = filtered['removed'].str.lower() + '|||' + filtered['added'].str.lower()
    seen = set()
    for _, row in filtered.iterrows():
        if row['key'] in seen:
            continue
        seen.add(row['key'])
        front = f"❌ {row['removed']}"
        back  = f"✅ {row['added']}<br><br><small>Category: {row['category']}<br>Context: ...{row['context']}...</small>"
        tag   = row['category'].lower().replace(' ','_').replace('/','_')
        cards.append([front, back, tag])
        if len(cards) >= max_cards:
            break
    return cards

pair_cards = make_anki_pair_cards(changes_df)
pair_path = os.path.join(OUT_DIR, 'anki_corrections.csv')
with open(pair_path, 'w', newline='', encoding='utf-8') as f:
    w = csv.writer(f)
    w.writerow(['Front', 'Back', 'Tags'])
    w.writerows(pair_cards)
print(f"Saved {len(pair_cards)} pair cards → {pair_path}")
# Out:
# Saved 500 pair cards → /Users/haewon.yum/Documents/ESL/anki_corrections.csv

# %%
# --- Anki Card 2: Pattern summary cards (one per category) ---

def make_pattern_cards(changes_df):
    """Create one card per error category with top examples."""
    cards = []
    for cat, grp in changes_df.groupby('category'):
        examples = (
            grp[grp['removed'].str.len() > 1]
            .assign(pair=grp['removed'].str[:40] + ' → ' + grp['added'].str[:40])
            ['pair'].value_counts().head(5)
        )
        ex_html = '<br>'.join([f'• {p} ({c}x)' for p, c in examples.items()])
        front = f"Pattern: <b>{cat}</b><br><small>({len(grp)} corrections total)</small>"
        back  = f"Common corrections:<br><br>{ex_html}"
        tag   = 'pattern_card ' + cat.lower().replace(' ','_').replace('/','_')
        cards.append([front, back, tag])
    return cards

pattern_cards = make_pattern_cards(changes_df)
pat_path = os.path.join(OUT_DIR, 'anki_patterns.csv')
with open(pat_path, 'w', newline='', encoding='utf-8') as f:
    w = csv.writer(f)
    w.writerow(['Front', 'Back', 'Tags'])
    w.writerows(pattern_cards)
print(f"Saved {len(pattern_cards)} pattern cards → {pat_path}")
print("\n✅ Done! Import the CSV files into Anki:")
print(f"   1. {pair_path}")
print(f"   2. {pat_path}")
# Out:
# Saved 8 pattern cards → /Users/haewon.yum/Documents/ESL/anki_patterns.csv
#
# ✅ Done! Import the CSV files into Anki:
#    1. /Users/haewon.yum/Documents/ESL/anki_corrections.csv
#    2. /Users/haewon.yum/Documents/ESL/anki_patterns.csv

# %% [markdown]
# ## 5 — Deep Dive: Spot-check by Category
#
# Browse specific corrections for any error type.

# %%
# Change CATEGORY to explore a specific type
CATEGORY = 'Article (a/an/the)'   # or 'Preposition', 'Word choice / phrasing', etc.

sub = changes_df[changes_df['category'] == CATEGORY]
print(f"Category: {CATEGORY} — {len(sub)} total corrections\n")

# Show top corrections with context
top = sub.assign(
    pair=sub['removed'].str[:40] + ' → ' + sub['added'].str[:40]
).groupby('pair').agg(
    count=('pair','size'),
    example=('context','first')
).sort_values('count', ascending=False).head(20)

for pair_str, row in top.iterrows():
    print(f"  {row['count']:3d}x  {pair_str}")
    print(f"         Context: ...{row['example'][:80]}...\n")
# Out:
# Category: Article (a/an/the) — 1320 total corrections
#
#    88x   → the
#          Context: ...a sync with Sales team to...
#
#    39x   → a
#          Context: ...that I have very limited timeline...
#
#    25x  proofread: →
#          Context: ...proofread: Hi, I want...
#
#    20x  the →
#          Context: ...quantities, price, and the Amazon link: https://docs.google.com/spreadsheets/d/1...
#
#    10x  Proofread: →
#          Context: ...Proofread: @hedan.zeng@moloco.com Hi hedan,...
#
#     8x   → an
#          Context: ...data scientist in ad tech company,...
#
#     8x  the → a
#          Context: ...pain points from the sales perspective. They...
#
#     7x   → -
#          Context: ...GDS or APAC? How for each...
#
#     6x   → also
#          Context: ...as the doctor prescribed other medications...
#
#     6x  a → the
#          Context: ...model performance, and a spike in the...
#
#     5x  of →
#          Context: ...reached approximately 50% of SoR, meaning that...
#
#     5x   → I
#          Context: ...at this and welcome any feedback!...
#
#     5x   → and
#          Context: ...have mattress, cover, 4 sides of...
#
#     5x  a →
#          Context: ...cansider this account a high potential?...
#
#     5x   → in
#          Context: ...terms of spending both in Q1/Q2....
#
#     5x   → that
#          Context: ...slack channel but could be another...
#
#     4x  only →
#          Context: ...are curruntly running only either iOS or...
#
#     4x   → has
#          Context: ...Haewon: Our SoR already has been...
#
#     4x   → have
#          Context: ...you that I submitted the deferral...
#
#     4x   → if
#          Context: ...would be great we can connect...
