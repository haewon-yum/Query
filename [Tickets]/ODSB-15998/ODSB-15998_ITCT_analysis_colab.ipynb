# %% [markdown]
# # ODSB-15998: ITCT Analysis - All Clicks by IP
#
# **Objective:** Analyze Impression-to-Click Time (ITCT) patterns for ALL clicks and identify if abnormal behaviors come from specific IPs.
#
# **Advertiser:** `h4khOQuVmBR7OV2S`
# **Period:** 2026-01-01 to 2026-01-20
#
# **Approach:** Analyze IP patterns at user level (not limited to 30+ click MTIDs)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/)
#
# **Note:** Run the authentication cell below first before executing any BigQuery queries.

# %%
# ===========================================
# Google Colab Authentication (Run this first)
# ===========================================
from google.colab import auth
auth.authenticate_user()
print('✓ Authenticated successfully!')

# %%
# Setup (Authentication handled in cell above)
from google.cloud import bigquery
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

client = bigquery.Client(project='moloco-ods')

# Configuration
ADVERTISER_ID = 'h4khOQuVmBR7OV2S'
START_DATE = '2026-01-01'
END_DATE = '2026-01-20'
MIN_CLICK_THRESHOLD = 30

print(f'Advertiser: {ADVERTISER_ID}')
print(f'Period: {START_DATE} to {END_DATE}')
print(f'Click Threshold: {MIN_CLICK_THRESHOLD}+ clicks per MTID')
# Out:
# Advertiser: h4khOQuVmBR7OV2S
# Period: 2026-01-01 to 2026-01-20
# Click Threshold: 30+ clicks per MTID

# %%
#@title Step 1: Q1 - Compare click vs click_surplus tables (clicks per MTID)

# Q1: Does click table have only 1 click per MTID? vs click_surplus has multiple?
query_click_comparison = f"""
WITH click_table AS (
    SELECT
        bid.mtid,
        COUNT(*) AS click_count
    FROM `focal-elf-631.prod_stream_view.click`
    WHERE api.advertiser.id = '{ADVERTISER_ID}'
        AND timestamp BETWEEN '{START_DATE}' AND '{END_DATE}'
    GROUP BY bid.mtid
),
click_surplus_table AS (
    SELECT
        bid.mtid,
        COUNT(*) AS click_count
    FROM `focal-elf-631.prod_stream_view.click_surplus`
    WHERE api.advertiser.id = '{ADVERTISER_ID}'
        AND timestamp BETWEEN '{START_DATE}' AND '{END_DATE}'
    GROUP BY bid.mtid
)

SELECT
    'click' AS table_name,
    COUNT(*) AS total_mtids,
    SUM(click_count) AS total_clicks,
    AVG(click_count) AS avg_clicks_per_mtid,
    MAX(click_count) AS max_clicks_per_mtid,
    COUNTIF(click_count = 1) AS mtids_with_1_click,
    COUNTIF(click_count > 1) AS mtids_with_multiple_clicks
FROM click_table

UNION ALL

SELECT
    'click_surplus' AS table_name,
    COUNT(*) AS total_mtids,
    SUM(click_count) AS total_clicks,
    AVG(click_count) AS avg_clicks_per_mtid,
    MAX(click_count) AS max_clicks_per_mtid,
    COUNTIF(click_count = 1) AS mtids_with_1_click,
    COUNTIF(click_count > 1) AS mtids_with_multiple_clicks
FROM click_surplus_table
"""

df_click_comparison = client.query(query_click_comparison).to_dataframe()
print("=" * 70)
print("Q1: Click vs Click_Surplus Table Comparison")
print("=" * 70)
print(df_click_comparison.to_string(index=False))
print("\n→ If click table has mostly 1 click per MTID, it logs only the FIRST valid click.")

query_suspicious_mtid = f"""
WITH event AS (
    SELECT
        req.device.ifa,
        req.exchange,
        req.app.bundle,
        req.app.publisher.id AS publisher_id,
        req.app.publisher.name AS publisher_name,
        req.imp.tagid,
        cv.pb.event.name as event_name,
        cv.received_at as event_timestamp,
        bid.timestamp as bid_timestamp,
        imp.received_at as imp_timestamp,
        click.received_at as click_timestamp,
        REGEXP_EXTRACT(cv.pb.payload.raw, r'&moloco_mtid=([^&]*)') AS mtid_value,
    FROM `focal-elf-631.prod_stream_view.cv`
    WHERE api.advertiser.id = '{ADVERTISER_ID}'
        AND timestamp BETWEEN '{START_DATE}' AND '{END_DATE}'
)

SELECT
    ifa,
    exchange,
    bundle,
    tagid,
    mtid_value,
    event_name,
    COUNT(DISTINCT click_timestamp) AS click_cnt,
    COUNT(DISTINCT event_timestamp) AS event_cnt
FROM event
WHERE event_name = 'deeplink'
GROUP BY ALL
HAVING event_cnt > {MIN_CLICK_THRESHOLD}
ORDER BY event_cnt DESC
"""

df_suspicious_mtid = client.query(query_suspicious_mtid).to_dataframe()
print(f"Suspicious MTIDs with {MIN_CLICK_THRESHOLD}+ clicks: {len(df_suspicious_mtid)}")
print(f"Unique IFAs: {df_suspicious_mtid['ifa'].nunique()}")
print(f"Unique Publishers: {df_suspicious_mtid['bundle'].nunique()}")
df_suspicious_mtid.head(20)
# Out:
# ======================================================================
# Q1: Click vs Click_Surplus Table Comparison
# ======================================================================
#    table_name  total_mtids  total_clicks  avg_clicks_per_mtid  max_clicks_per_mtid  mtids_with_1_click  mtids_with_multiple_clicks
#         click       757177        757179             1.000003                    2              757175                           2
# click_surplus       183465        387988             2.114779                  903              115022                       68443
#
# → If click table has mostly 1 click per MTID, it logs only the FIRST valid click.
# Suspicious MTIDs with 30+ clicks: 22
# Unique IFAs: 5
# Unique Publishers: 3
#                                      ifa        exchange  \
# 0   739e2e23-4d76-44b9-9067-3a8676c6e2ae           ADPIE
# 1   739e2e23-4d76-44b9-9067-3a8676c6e2ae           ADPIE
# 2   cb16bfcd-608f-42a6-abe4-738ba75bdb1e           ADPIE
# 3   cb16bfcd-608f-42a6-abe4-738ba75bdb1e           ADPIE
# 4   5b260e61-b287-4fa6-b85d-7206dc51192c           ADPIE
# 5   cb16bfcd-608f-42a6-abe4-738ba75bdb1e           ADPIE
# 6   cb16bfcd-608f-42a6-abe4-738ba75bdb1e           ADPIE
# 7   cb16bfcd-608f-42a6-abe4-738ba75bdb1e           ADPIE
# 8   739e2e23-4d76-44b9-9067-3a8676c6e2ae           ADPIE
# 9   739e2e23-4d76-44b9-9067-3a8676c6e2ae           ADPIE
# 10  2e0054ce-7983-4119-84eb-b45dff5a3250  MOLOCO_SDK_MAX
# 11  7c1a5950-fda3-4a22-8171-926ad14bf2ee  MOLOCO_SDK_MAX
# 12  739e2e23-4d76-44b9-9067-3a8676c6e2ae           ADPIE
# 13  739e2e23-4d76-44b9-9067-3a8676c6e2ae           ADPIE
# 14  cb16bfcd-608f-42a6-abe4-738ba75bdb1e           ADPIE
# 15  739e2e23-4d76-44b9-9067-3a8676c6e2ae           ADPIE
# 16  cb16bfcd-608f-42a6-abe4-738ba75bdb1e           ADPIE
# 17  cb16bfcd-608f-42a6-abe4-738ba75bdb1e           ADPIE
# 18  739e2e23-4d76-44b9-9067-3a8676c6e2ae           ADPIE
# 19  5b260e61-b287-4fa6-b85d-7206dc51192c           ADPIE
#
#                      bundle  \
# 0                  com.ltlk
# 1                  com.ltlk
# 2                  com.ltlk
# 3                  com.ltlk
# 4                  com.ltlk
# 5                  com.ltlk
# 6                  com.ltlk
# 7                  com.ltlk
# 8                  com.ltlk
# 9                  com.ltlk
# 10         com.block.juggle
# 11  com.ovivo.pizza.perfect
# 12                 com.ltlk
# 13                 com.ltlk
# 14                 com.ltlk
# 15                 com.ltlk
# 16                 com.ltlk
# 17                 com.ltlk
# 18                 com.ltlk
# 19                 com.ltlk
#
#                                                 tagid  \
# 0   56b4002f7174ea39c74df8aa:6628a58e8c8d1d780dbb6ffb
# 1   56b4002f7174ea39c74df8aa:6628a58e8c8d1d780dbb6ffb
# 2   56b4002f7174ea39c74df8aa:6628a58e8c8d1d780dbb6ffb
# 3   56b4002f7174ea39c74df8aa:6618f23e8c8d1d6afd52744e
# 4   56b4002f7174ea39c74df8aa:6618f23e8c8d1d6afd52744e
# 5   56b4002f7174ea39c74df8aa:6618f2638c8d1d6a54cdc3ae
# 6   56b4002f7174ea39c74df8aa:6618f23e8c8d1d6afd52744e
# 7   56b4002f7174ea39c74df8aa:6628a58e8c8d1d780dbb6ffb
# 8   56b4002f7174ea39c74df8aa:6618f23e8c8d1d6afd52744e
# 9   56b4002f7174ea39c74df8aa:6628a58e8c8d1d780dbb6ffb
# 10                                   jrArUvZiowyngJkN
# 11                                   vzo72JYFkbKS7Yqv
# 12  56b4002f7174ea39c74df8aa:6618f23e8c8d1d6afd52744e
# 13  56b4002f7174ea39c74df8aa:6628a58e8c8d1d780dbb6ffb
# 14  56b4002f7174ea39c74df8aa:6628a58e8c8d1d780dbb6ffb
# 15  56b4002f7174ea39c74df8aa:6618f23e8c8d1d6afd52744e
# 16  56b4002f7174ea39c74df8aa:6628a58e8c8d1d780dbb6ffb
# 17  56b4002f7174ea39c74df8aa:6618f23e8c8d1d6afd52744e
# 18  56b4002f7174ea39c74df8aa:6618f23e8c8d1d6afd52744e
# 19  56b4002f7174ea39c74df8aa:6618f2638c8d1d6a54cdc3ae
#
#                                            mtid_value event_name  click_cnt  \
# 0   ChD8thKOosFLo4Prqygk1MwwEJ-t-coGGhQIARoQc54uI0...   deeplink          1
# 1   ChD4ENFwgKJL0Z10t6KEz-HFEPH1qMsGGhQIARoQc54uI0...   deeplink          1
# 2   ChBXmcUT7AdKkp55mndOhCCjELnnh8sGGhQIARoQyxa_zW...   deeplink          1
# 3   ChAYOrqG-9hDt6j_RSmX9j54EIai3soGGhQIARoQyxa_zW...   deeplink          1
# 4   ChDfwQk0xkVMibkE9AzZxlaCEIjS_MoGGhQIARoQWyYOYb...   deeplink          1
# 5   ChA3B5QBdQNC8ZY8RAjU_oxfEN3u_coGGhQIARoQyxa_zW...   deeplink          1
# 6   ChAkgf4DrjpC6pCJqxj1KK6VENXph8sGGhQIARoQyxa_zW...   deeplink          1
# 7   ChC60Xox4LVH2YqjgVKIE23jEP2h3soGGhQIARoQyxa_zW...   deeplink          1
# 8   ChCnX1CR6xdG4oI93PF0t_QlEKet-coGGhQIARoQc54uI0...   deeplink          1
# 9   ChBSpImwJ_xOvoNACMPrcbySEI-45MoGGhQIARoQc54uI0...   deeplink          1
# 10  ChA9Q0gKmspBKLaOb-TP5NJTENH0l8sGGhQIARoQLgBUzn...   deeplink          1
# 11  ChDydSTq3WxL0ICYyUfPL36pEMWEsssGGhQIARoQfBpZUP...   deeplink          1
# 12  ChB4wbBvr6FG7JNpS3UnD7DhENXKossGGhQIARoQc54uI0...   deeplink          1
# 13  ChBx6KGkF0FOCY_8RmolH7BzEP_g_soGGhQIARoQc54uI0...   deeplink          1
# 14  ChD3XaGl6zdEToPKdvP3XyzXEMDn_coGGhQIARoQyxa_zW...   deeplink          1
# 15  ChC0C_z_HNdAh7uk15D7cb-rEOz1qMsGGhQIARoQc54uI0...   deeplink          1
# 16  ChA95nAfI3JIbLNW14XNdbvEEMThjcsGGhQIARoQyxa_zW...   deeplink          1
# 17  ChAEuG6OwmFHGpq6FLzTzWRTENDn_coGGhQIARoQyxa_zW...   deeplink          1
# 18  ChBazcJheEtFUKhTJk9ub-g0EM_KossGGhQIARoQc54uI0...   deeplink          1
# 19  ChA20c8KhpdEkYM3RrMzFGYJEJKL6soGGhQIARoQWyYOYb...   deeplink          1
#
#     event_cnt
# 0          96
# 1          79
# 2          74
# 3          70
# 4          62
# 5          61
# 6          60
# 7          59
# 8          54
# 9          47
# 10         46
# 11         44
# 12         44
# 13         39
# 14         38
# 15         36
# 16         36
# 17         35
# 18         33
# 19         32

# %%
#@title Step 1-1: Q1-1 - Deeplink Event Time vs Click Time Comparison

query_deeplink_vs_click = f"""
WITH deeplink_events AS (
    SELECT
        REGEXP_EXTRACT(cv.pb.payload.raw, r'&moloco_mtid=([^&]*)') AS mtid_value,
        cv.received_at AS deeplink_timestamp,
        req.device.ifa
    FROM `focal-elf-631.prod_stream_view.cv`
    WHERE api.advertiser.id = '{ADVERTISER_ID}'
        AND timestamp BETWEEN '{START_DATE}' AND '{END_DATE}'
        AND cv.pb.event.name = 'deeplink'
),
click_surplus_events AS (
    SELECT
        bid.mtid,
        click.happened_at AS click_timestamp,
        req.device.ifa
    FROM `focal-elf-631.prod_stream_view.click_surplus`
    WHERE api.advertiser.id = '{ADVERTISER_ID}'
        AND timestamp BETWEEN '{START_DATE}' AND '{END_DATE}'
)

SELECT
    d.mtid_value,
    d.ifa,
    d.deeplink_timestamp,
    c.click_timestamp,
    TIMESTAMP_DIFF(d.deeplink_timestamp, c.click_timestamp, SECOND) AS deeplink_minus_click_sec
FROM deeplink_events d
JOIN click_surplus_events c
    ON d.mtid_value = c.mtid AND d.ifa = c.ifa
WHERE d.mtid_value IS NOT NULL
ORDER BY ABS(TIMESTAMP_DIFF(d.deeplink_timestamp, c.click_timestamp, SECOND)) DESC
LIMIT 1000
"""

df_deeplink_vs_click = client.query(query_deeplink_vs_click).to_dataframe()

print("=" * 70)
print("Q1-1: Deeplink Event Time vs Click Time (click_surplus)")
print("=" * 70)
print(f"\nSample size: {len(df_deeplink_vs_click)}")
print(f"\nTime Difference (deeplink - click) in seconds:")
print(df_deeplink_vs_click['deeplink_minus_click_sec'].describe())

print(f"\nDistribution of time difference:")
bins = [-float('inf'), -60, -10, -1, 0, 1, 10, 60, float('inf')]
labels = ['<-60s', '-60 to -10s', '-10 to -1s', '-1 to 0s', '0 to 1s', '1 to 10s', '10 to 60s', '>60s']
df_deeplink_vs_click['diff_bucket'] = pd.cut(df_deeplink_vs_click['deeplink_minus_click_sec'], bins=bins, labels=labels)
print(df_deeplink_vs_click['diff_bucket'].value_counts().sort_index())


query_itct = f"""
SELECT
    req.device.ifa,
    req.device.ip,
    bid.mtid,
    req.exchange,
    req.app.bundle,
    req.app.publisher.id AS publisher_id,
    req.app.publisher.name AS publisher_name,
    req.imp.tagid,
    imp.happened_at AS imp_timestamp,
    click.happened_at AS click_timestamp,
    TIMESTAMP_DIFF(click.happened_at, imp.happened_at, MILLISECOND) AS itct_ms,
    TIMESTAMP_DIFF(click.happened_at, imp.happened_at, SECOND) AS itct_sec,
    click_surplus.reason AS click_surplus_reason
FROM `focal-elf-631.prod_stream_view.click_surplus`
WHERE api.advertiser.id = '{ADVERTISER_ID}'
    AND timestamp BETWEEN '{START_DATE}' AND '{END_DATE}'
ORDER BY req.device.ifa, imp.happened_at, click.happened_at
"""

df_itct = client.query(query_itct).to_dataframe()
print(f"Total click records: {len(df_itct):,}")
print(f"Unique IFAs: {df_itct['ifa'].nunique():,}")
print(f"Unique IPs: {df_itct['ip'].nunique():,}")
print(f"Unique MTIDs: {df_itct['mtid'].nunique():,}")
df_itct.head(20)
# Out:
# ======================================================================
# Q1-1: Deeplink Event Time vs Click Time (click_surplus)
# ======================================================================
#
# Sample size: 1000
#
# Time Difference (deeplink - click) in seconds:
# count         1000.0
# mean       66539.397
# std      14871.32364
# min        -225656.0
# 25%          57656.0
# 50%          65367.5
# 75%         75966.25
# max         111364.0
# Name: deeplink_minus_click_sec, dtype: Float64
#
# Distribution of time difference:
# diff_bucket
# <-60s            2
# -60 to -10s      0
# -10 to -1s       0
# -1 to 0s         0
# 0 to 1s          0
# 1 to 10s         0
# 10 to 60s        0
# >60s           998
# Name: count, dtype: int64
# Total click records: 387,988
# Unique IFAs: 77,177
# Unique IPs: 80,106
# Unique MTIDs: 183,465
#    ifa           ip                                               mtid  \
# 0        118.235.74  ChCwstJd-aFA3a7QnHjpL3lYEJHT2coGGhQIBRoQs33h20...
# 1        211.235.90  ChBmnX1rCXdI6pu2fxuMk2AKELSl7coGGhQIBRoQtb8txE...
# 2       106.101.196  ChCYGPN4kHlLQYgx3Yg9oNRYENDu7coGGhQIBRoQOflZ0D...
# 3        211.235.80  ChCmIAhi7tVEXqpYouE2FiNsEILRicsGGhQIBRoQW3-a4v...
# 4        118.235.92  ChAawPwaLtxMW7oyCNtWzdyjEK312MoGGhQIBRoQq43vKB...
# 5        182.231.26  ChAhFGMTzRlNJLsujzL3GFNQEJac2coGGhQIBRoQgJE3iZ...
# 6        106.101.80  ChC2xoYX5u1E15ImgrnZh9NuEJPa2soGGhQIBRoQouqYpb...
# 7         223.39.80  ChAaee1rrnJOHJ40NO0yqwv2EIan3MoGGhQIBRoQaqvwaz...
# 8        106.101.69  ChDAJwzuh7VCrJw7w6jNmKU4EO2i3soGGhQIBRoQYmVQ0l...
# 9        211.235.88  ChAVJ43pDaZHgK8GPgDvHHeIEJjR4coGGhQIBRoQIzbIzb...
# 10       106.101.77  ChBB8uKx2oxDTp7BSZhFFCStEL6Y4soGGhQIBRoQLTC8f1...
# 11       211.235.75  ChCDBj2wekZMr5g5K5fWdWYtEOyD48oGGhQIBRoQ-8auvz...
# 12       118.235.84  ChDnmVzcQ5BCEoQmTE9dgPs0EMi_48oGGhQIBRoQ3U-w-p...
# 13       211.235.97  ChC3uudm-HpA66OoW84XYHOQEPPP48oGGhQIBRoQjlJYxz...
# 14       122.35.100  ChDCER-oqlNId60dUqJeVoTsEOHd5MoGGhQIBRoQ5eJ1nZ...
# 15      211.234.206  ChBzVQ264lNNj5NQWg5JBTnFEO2B58oGGhQIBRoQCQacYS...
# 16       106.101.75  ChCB8ZK9k91IBLCgG4ezIeCCEOrP6MoGGhQIBRoQ6fdOhK...
# 17       118.235.85  ChDJegKdet1EkrSGBxlJbtyXEPnl6coGGhQIBRoQ8YOdwM...
# 18       220.79.176  ChAEOwV9kdtCHIVDC2SFHU-uEIi96soGGhQIBRoQnTcjWl...
# 19      211.234.204  ChB9h8SUOOVFbpBufYFRYL3nEN_m68oGGhQIBRoQ2kyrjZ...
#
#    exchange                 bundle publisher_id    publisher_name  \
# 0     KAKAO         com.kakao.talk            0  Daum Kakao Corp.
# 1     KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 2     KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 3     KAKAO         com.kakao.talk            0  Daum Kakao Corp.
# 4     KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 5     KAKAO       com.jobkorea.app          vOc           GENERAL
# 6     KAKAO         com.kakao.talk            0  Daum Kakao Corp.
# 7     KAKAO    com.skt.prod.dialer          leN           GENERAL
# 8     KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 9     KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 10    KAKAO         com.kakao.talk          1v8              TALK
# 11    KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 12    KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 13    KAKAO         com.kakao.talk            0  Daum Kakao Corp.
# 14    KAKAO        com.ktcs.whowho          nYU           GENERAL
# 15    KAKAO         com.kakao.talk            0  Daum Kakao Corp.
# 16    KAKAO         com.kakao.talk          1v8              TALK
# 17    KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 18    KAKAO        com.albamon.app          vOc           GENERAL
# 19    KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
#
#                    tagid                    imp_timestamp  \
# 0   DAN-9PaWqQNQpqtf5FFM                              NaT
# 1   DAN-fu8OO1UnClBkAZJI                              NaT
# 2   DAN-fXGthnQXmT8bskWu                              NaT
# 3   DAN-eIoAe5gVGnPuUvys                              NaT
# 4      DAN-1ib3qn9ggkhtc 2026-01-01 09:13:17.514568+00:00
# 5   DAN-BjCQma5Oay7mt7HU 2026-01-01 10:36:08.365337+00:00
# 6   DAN-kUTB5NrFaPR9bAKq 2026-01-01 17:21:24.625163+00:00
# 7   DAN-D765XmBR7qyQcGdU 2026-01-02 00:38:32.572828+00:00
# 8   DAN-fXGthnQXmT8bskWu 2026-01-02 09:35:42.012723+00:00
# 9      DAN-1iykzv03dd4rq 2026-01-03 00:53:45.344225+00:00
# 10      DAN-rhdt40s88rht 2026-01-03 03:25:52.673619+00:00
# 11  DAN-fXGthnQXmT8bskWu 2026-01-03 07:14:52.806972+00:00
# 12  DAN-fXGthnQXmT8bskWu 2026-01-03 09:22:17.446554+00:00
# 13  DAN-zxAc7udqU4LJBVmS 2026-01-03 09:57:08.794457+00:00
# 14  DAN-JCEammhyEG8rEnRT 2026-01-03 14:59:46.433641+00:00
# 15  DAN-zxAc7udqU4LJBVmS 2026-01-04 01:22:54.613855+00:00
# 16  DAN-sH6Ix7IltyPMTHeT 2026-01-04 08:42:19.786140+00:00
# 17  DAN-fXGthnQXmT8bskWu 2026-01-04 14:02:35.199284+00:00
# 18  DAN-peuiQrKcdWMnXMIT 2026-01-04 17:08:24.499160+00:00
# 19  DAN-Baql7m2lUrBsWmKY 2026-01-04 23:10:24.863183+00:00
#
#                     click_timestamp  itct_ms  itct_sec  \
# 0  2026-01-01 12:33:27.815026+00:00     <NA>      <NA>
# 1  2026-01-05 05:57:09.314092+00:00     <NA>      <NA>
# 2  2026-01-05 08:33:21.933582+00:00     <NA>      <NA>
# 3  2026-01-10 14:56:03.319808+00:00     <NA>      <NA>
# 4  2026-01-01 09:13:28.069705+00:00    10555        10
# 5  2026-01-01 10:36:37.841352+00:00    29476        29
# 6  2026-01-01 17:21:25.822350+00:00     1197         1
# 7  2026-01-02 00:38:40.328680+00:00     7755         7
# 8  2026-01-02 09:35:43.421316+00:00     1408         1
# 9  2026-01-03 00:53:51.888636+00:00     6544         6
# 10 2026-01-03 03:34:34.494074+00:00   521820       521
# 11 2026-01-03 07:14:53.341231+00:00      534         0
# 12 2026-01-03 09:22:35.247673+00:00    17801        17
# 13 2026-01-03 09:57:14.682688+00:00     5888         5
# 14 2026-01-03 14:59:49.339390+00:00     2905         2
# 15 2026-01-04 01:22:59.297623+00:00     4683         4
# 16 2026-01-04 08:42:31.161628+00:00    11375        11
# 17 2026-01-04 14:02:41.007494+00:00     5808         5
# 18 2026-01-04 17:09:03.772300+00:00    39273        39
# 19 2026-01-04 23:10:27.810577+00:00     2947         2
#
#               click_surplus_reason
# 0             IGNORE_REPORT_TO_MMP
# 1             IGNORE_REPORT_TO_MMP
# 2             IGNORE_REPORT_TO_MMP
# 3             IGNORE_REPORT_TO_MMP
# 4   IGNORE_REPORT_TO_MMP,REDUNDANT
# 5   IGNORE_REPORT_TO_MMP,REDUNDANT
# 6   IGNORE_REPORT_TO_MMP,REDUNDANT
# 7   IGNORE_REPORT_TO_MMP,REDUNDANT
# 8   IGNORE_REPORT_TO_MMP,REDUNDANT
# 9   IGNORE_REPORT_TO_MMP,REDUNDANT
# 10  IGNORE_REPORT_TO_MMP,REDUNDANT
# 11  IGNORE_REPORT_TO_MMP,REDUNDANT
# 12  IGNORE_REPORT_TO_MMP,REDUNDANT
# 13  IGNORE_REPORT_TO_MMP,REDUNDANT
# 14  IGNORE_REPORT_TO_MMP,REDUNDANT
# 15  IGNORE_REPORT_TO_MMP,REDUNDANT
# 16  IGNORE_REPORT_TO_MMP,REDUNDANT
# 17  IGNORE_REPORT_TO_MMP,REDUNDANT
# 18  IGNORE_REPORT_TO_MMP,REDUNDANT
# 19  IGNORE_REPORT_TO_MMP,REDUNDANT

# %%
#@title Step 2: Get ITCT (Impression to Click Time) with IP for ALL Clicks

query_itct = f"""
SELECT
    req.device.ifa,
    req.device.ip,
    bid.mtid,
    req.exchange,
    req.app.bundle,
    req.app.publisher.id AS publisher_id,
    req.app.publisher.name AS publisher_name,
    req.imp.tagid,
    imp.happened_at AS imp_timestamp,
    click.happened_at AS click_timestamp,
    TIMESTAMP_DIFF(click.happened_at, imp.happened_at, MILLISECOND) AS itct_ms,
    TIMESTAMP_DIFF(click.happened_at, imp.happened_at, SECOND) AS itct_sec,
    click_surplus.reason AS click_surplus_reason
FROM `focal-elf-631.prod_stream_view.click_surplus`
WHERE api.advertiser.id = '{ADVERTISER_ID}'
    AND timestamp BETWEEN '{START_DATE}' AND '{END_DATE}'
ORDER BY req.device.ifa, imp.happened_at, click.happened_at
"""

df_itct = client.query(query_itct).to_dataframe()
print(f"Total click records: {len(df_itct):,}")
print(f"Unique IFAs: {df_itct['ifa'].nunique():,}")
print(f"Unique IPs: {df_itct['ip'].nunique():,}")
print(f"Unique MTIDs: {df_itct['mtid'].nunique():,}")
df_itct.head(20)
# Out:
# Total click records: 387,988
# Unique IFAs: 77,177
# Unique IPs: 80,106
# Unique MTIDs: 183,465
#    ifa           ip                                               mtid  \
# 0        118.235.74  ChCwstJd-aFA3a7QnHjpL3lYEJHT2coGGhQIBRoQs33h20...
# 1        211.235.90  ChBmnX1rCXdI6pu2fxuMk2AKELSl7coGGhQIBRoQtb8txE...
# 2       106.101.196  ChCYGPN4kHlLQYgx3Yg9oNRYENDu7coGGhQIBRoQOflZ0D...
# 3        211.235.80  ChCmIAhi7tVEXqpYouE2FiNsEILRicsGGhQIBRoQW3-a4v...
# 4        118.235.92  ChAawPwaLtxMW7oyCNtWzdyjEK312MoGGhQIBRoQq43vKB...
# 5        182.231.26  ChAhFGMTzRlNJLsujzL3GFNQEJac2coGGhQIBRoQgJE3iZ...
# 6        106.101.80  ChC2xoYX5u1E15ImgrnZh9NuEJPa2soGGhQIBRoQouqYpb...
# 7         223.39.80  ChAaee1rrnJOHJ40NO0yqwv2EIan3MoGGhQIBRoQaqvwaz...
# 8        106.101.69  ChDAJwzuh7VCrJw7w6jNmKU4EO2i3soGGhQIBRoQYmVQ0l...
# 9        211.235.88  ChAVJ43pDaZHgK8GPgDvHHeIEJjR4coGGhQIBRoQIzbIzb...
# 10       106.101.77  ChBB8uKx2oxDTp7BSZhFFCStEL6Y4soGGhQIBRoQLTC8f1...
# 11       211.235.75  ChCDBj2wekZMr5g5K5fWdWYtEOyD48oGGhQIBRoQ-8auvz...
# 12       118.235.84  ChDnmVzcQ5BCEoQmTE9dgPs0EMi_48oGGhQIBRoQ3U-w-p...
# 13       211.235.97  ChC3uudm-HpA66OoW84XYHOQEPPP48oGGhQIBRoQjlJYxz...
# 14       122.35.100  ChDCER-oqlNId60dUqJeVoTsEOHd5MoGGhQIBRoQ5eJ1nZ...
# 15      211.234.206  ChBzVQ264lNNj5NQWg5JBTnFEO2B58oGGhQIBRoQCQacYS...
# 16       106.101.75  ChCB8ZK9k91IBLCgG4ezIeCCEOrP6MoGGhQIBRoQ6fdOhK...
# 17       118.235.85  ChDJegKdet1EkrSGBxlJbtyXEPnl6coGGhQIBRoQ8YOdwM...
# 18       220.79.176  ChAEOwV9kdtCHIVDC2SFHU-uEIi96soGGhQIBRoQnTcjWl...
# 19      211.234.204  ChB9h8SUOOVFbpBufYFRYL3nEN_m68oGGhQIBRoQ2kyrjZ...
#
#    exchange                 bundle publisher_id    publisher_name  \
# 0     KAKAO         com.kakao.talk            0  Daum Kakao Corp.
# 1     KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 2     KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 3     KAKAO         com.kakao.talk            0  Daum Kakao Corp.
# 4     KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 5     KAKAO       com.jobkorea.app          vOc           GENERAL
# 6     KAKAO         com.kakao.talk            0  Daum Kakao Corp.
# 7     KAKAO    com.skt.prod.dialer          leN           GENERAL
# 8     KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 9     KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 10    KAKAO         com.kakao.talk          1v8              TALK
# 11    KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 12    KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 13    KAKAO         com.kakao.talk            0  Daum Kakao Corp.
# 14    KAKAO        com.ktcs.whowho          nYU           GENERAL
# 15    KAKAO         com.kakao.talk            0  Daum Kakao Corp.
# 16    KAKAO         com.kakao.talk          1v8              TALK
# 17    KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
# 18    KAKAO        com.albamon.app          vOc           GENERAL
# 19    KAKAO  net.daum.android.daum            0  Daum Kakao Corp.
#
#                    tagid                    imp_timestamp  \
# 0   DAN-9PaWqQNQpqtf5FFM                              NaT
# 1   DAN-fu8OO1UnClBkAZJI                              NaT
# 2   DAN-fXGthnQXmT8bskWu                              NaT
# 3   DAN-eIoAe5gVGnPuUvys                              NaT
# 4      DAN-1ib3qn9ggkhtc 2026-01-01 09:13:17.514568+00:00
# 5   DAN-BjCQma5Oay7mt7HU 2026-01-01 10:36:08.365337+00:00
# 6   DAN-kUTB5NrFaPR9bAKq 2026-01-01 17:21:24.625163+00:00
# 7   DAN-D765XmBR7qyQcGdU 2026-01-02 00:38:32.572828+00:00
# 8   DAN-fXGthnQXmT8bskWu 2026-01-02 09:35:42.012723+00:00
# 9      DAN-1iykzv03dd4rq 2026-01-03 00:53:45.344225+00:00
# 10      DAN-rhdt40s88rht 2026-01-03 03:25:52.673619+00:00
# 11  DAN-fXGthnQXmT8bskWu 2026-01-03 07:14:52.806972+00:00
# 12  DAN-fXGthnQXmT8bskWu 2026-01-03 09:22:17.446554+00:00
# 13  DAN-zxAc7udqU4LJBVmS 2026-01-03 09:57:08.794457+00:00
# 14  DAN-JCEammhyEG8rEnRT 2026-01-03 14:59:46.433641+00:00
# 15  DAN-zxAc7udqU4LJBVmS 2026-01-04 01:22:54.613855+00:00
# 16  DAN-sH6Ix7IltyPMTHeT 2026-01-04 08:42:19.786140+00:00
# 17  DAN-fXGthnQXmT8bskWu 2026-01-04 14:02:35.199284+00:00
# 18  DAN-peuiQrKcdWMnXMIT 2026-01-04 17:08:24.499160+00:00
# 19  DAN-Baql7m2lUrBsWmKY 2026-01-04 23:10:24.863183+00:00
#
#                     click_timestamp  itct_ms  itct_sec  \
# 0  2026-01-01 12:33:27.815026+00:00     <NA>      <NA>
# 1  2026-01-05 05:57:09.314092+00:00     <NA>      <NA>
# 2  2026-01-05 08:33:21.933582+00:00     <NA>      <NA>
# 3  2026-01-10 14:56:03.319808+00:00     <NA>      <NA>
# 4  2026-01-01 09:13:28.069705+00:00    10555        10
# 5  2026-01-01 10:36:37.841352+00:00    29476        29
# 6  2026-01-01 17:21:25.822350+00:00     1197         1
# 7  2026-01-02 00:38:40.328680+00:00     7755         7
# 8  2026-01-02 09:35:43.421316+00:00     1408         1
# 9  2026-01-03 00:53:51.888636+00:00     6544         6
# 10 2026-01-03 03:34:34.494074+00:00   521820       521
# 11 2026-01-03 07:14:53.341231+00:00      534         0
# 12 2026-01-03 09:22:35.247673+00:00    17801        17
# 13 2026-01-03 09:57:14.682688+00:00     5888         5
# 14 2026-01-03 14:59:49.339390+00:00     2905         2
# 15 2026-01-04 01:22:59.297623+00:00     4683         4
# 16 2026-01-04 08:42:31.161628+00:00    11375        11
# 17 2026-01-04 14:02:41.007494+00:00     5808         5
# 18 2026-01-04 17:09:03.772300+00:00    39273        39
# 19 2026-01-04 23:10:27.810577+00:00     2947         2
#
#               click_surplus_reason
# 0             IGNORE_REPORT_TO_MMP
# 1             IGNORE_REPORT_TO_MMP
# 2             IGNORE_REPORT_TO_MMP
# 3             IGNORE_REPORT_TO_MMP
# 4   IGNORE_REPORT_TO_MMP,REDUNDANT
# 5   IGNORE_REPORT_TO_MMP,REDUNDANT
# 6   IGNORE_REPORT_TO_MMP,REDUNDANT
# 7   IGNORE_REPORT_TO_MMP,REDUNDANT
# 8   IGNORE_REPORT_TO_MMP,REDUNDANT
# 9   IGNORE_REPORT_TO_MMP,REDUNDANT
# 10  IGNORE_REPORT_TO_MMP,REDUNDANT
# 11  IGNORE_REPORT_TO_MMP,REDUNDANT
# 12  IGNORE_REPORT_TO_MMP,REDUNDANT
# 13  IGNORE_REPORT_TO_MMP,REDUNDANT
# 14  IGNORE_REPORT_TO_MMP,REDUNDANT
# 15  IGNORE_REPORT_TO_MMP,REDUNDANT
# 16  IGNORE_REPORT_TO_MMP,REDUNDANT
# 17  IGNORE_REPORT_TO_MMP,REDUNDANT
# 18  IGNORE_REPORT_TO_MMP,REDUNDANT
# 19  IGNORE_REPORT_TO_MMP,REDUNDANT

# %%
#@title Step 2-1: Q2 - ITCT Comparison: Users with 30+ click MTIDs vs Normal Users (<5 clicks)

print("=" * 70)
print("Q2: Do users with suspicious MTIDs (30+ clicks) show delayed clicks?")
print("=" * 70)

# Calculate clicks per MTID
df_mtid_stats = df_itct.groupby(['mtid', 'ifa']).agg({
    'click_timestamp': 'count',
    'itct_sec': 'mean'
}).reset_index()
df_mtid_stats.columns = ['mtid', 'ifa', 'clicks_per_mtid', 'avg_itct_sec']

# Categorize MTIDs
df_mtid_stats['mtid_category'] = pd.cut(
    df_mtid_stats['clicks_per_mtid'],
    bins=[0, 1, 5, 30, float('inf')],
    labels=['1 click', '2-5 clicks', '6-30 clicks', '30+ clicks']
)

# Get unique IFAs per category
suspicious_ifas = set(df_mtid_stats[df_mtid_stats['clicks_per_mtid'] >= 30]['ifa'].unique())
normal_ifas = set(df_mtid_stats[df_mtid_stats['clicks_per_mtid'] < 5]['ifa'].unique())

# IFAs that are ONLY suspicious (never have normal MTIDs)
suspicious_only_ifas = suspicious_ifas - normal_ifas
normal_only_ifas = normal_ifas - suspicious_ifas

print(f"\nUser (IFA) Categories:")
print(f"  Users with 30+ click MTIDs: {len(suspicious_ifas):,}")
print(f"  Users with <5 click MTIDs: {len(normal_ifas):,}")
print(f"  Users with ONLY 30+ click MTIDs: {len(suspicious_only_ifas):,}")
print(f"  Users with ONLY <5 click MTIDs: {len(normal_only_ifas):,}")

# Compare ITCT by user category
df_itct['user_category'] = df_itct['ifa'].apply(
    lambda x: 'Suspicious Only' if x in suspicious_only_ifas 
    else ('Normal Only' if x in normal_only_ifas else 'Mixed')
)

print(f"\nITCT by User Category:")
itct_by_user = df_itct.groupby('user_category')['itct_sec'].agg(['count', 'mean', 'median', 'std']).round(2)
print(itct_by_user)

# ITCT distribution comparison
print(f"\nITCT Percentiles by User Category:")
for cat in ['Suspicious Only', 'Normal Only', 'Mixed']:
    subset = df_itct[df_itct['user_category'] == cat]['itct_sec']
    if len(subset) > 0:
        print(f"\n  {cat}:")
        for p in [0.25, 0.5, 0.75, 0.9, 0.95]:
            print(f"    P{int(p*100)}: {subset.quantile(p):.2f} sec")
# Out:
# ======================================================================
# Q2: Do users with suspicious MTIDs (30+ clicks) show delayed clicks?
# ======================================================================
#
# User (IFA) Categories:
#   Users with 30+ click MTIDs: 110
#   Users with <5 click MTIDs: 64,989
#   Users with ONLY 30+ click MTIDs: 63
#   Users with ONLY <5 click MTIDs: 64,942
#
# ITCT by User Category:
#                   count       mean  median        std
# user_category
# Mixed            112755   30298.13   202.0  180862.68
# Normal Only      231039    2974.36    21.0   97068.17
# Suspicious Only    4908  175852.14  4502.5  743159.73
#
# ITCT Percentiles by User Category:
#
#   Suspicious Only:
#     P25: 219.00 sec
#     P50: 4502.50 sec
#     P75: 29638.00 sec
#     P90: 194325.30 sec
#     P95: 876620.45 sec
#
#   Normal Only:
#     P25: 6.00 sec
#     P50: 21.00 sec
#     P75: 48.00 sec
#     P90: 162.00 sec
#     P95: 636.00 sec
#
#   Mixed:
#     P25: 68.00 sec
#     P50: 202.00 sec
#     P75: 12473.50 sec
#     P90: 38003.60 sec
#     P95: 129196.90 sec

# %%
#@title Step 2-2: Q3 - Patterns in Highly Delayed Clicks (ITCT > X seconds)
# Counting DISTINCT MTIDs (not clicks) - one MTID can have both delayed and normal clicks

print("=" * 70)
print("Q3: Patterns in Highly Delayed Clicks (by distinct MTID)")
print("=" * 70)

# Define delay thresholds
DELAY_THRESHOLD_SEC = 150  # Consider clicks >150 seconds as "highly delayed"

df_itct['is_delayed'] = df_itct['itct_sec'] > DELAY_THRESHOLD_SEC

# Get MTIDs with delayed/normal clicks
delayed_mtids = set(df_itct[df_itct['is_delayed']]['mtid'].unique())
normal_mtids = set(df_itct[~df_itct['is_delayed']]['mtid'].unique())
all_mtids = set(df_itct['mtid'].unique())

print(f"\nDelay Threshold: {DELAY_THRESHOLD_SEC} seconds")
print(f"Total unique MTIDs: {len(all_mtids):,}")
print(f"MTIDs with delayed clicks (>{DELAY_THRESHOLD_SEC}s): {len(delayed_mtids):,} ({len(delayed_mtids)/len(all_mtids)*100:.1f}%)")
print(f"MTIDs with normal clicks: {len(normal_mtids):,}")
print(f"MTIDs with BOTH delayed & normal: {len(delayed_mtids & normal_mtids):,}")

# Helper function to count distinct MTIDs by dimension
def count_mtids_by_dimension(df, dimension_cols):
    """Count distinct MTIDs with delayed/normal clicks per dimension"""
    if isinstance(dimension_cols, str):
        dimension_cols = [dimension_cols]
    
    # Get unique MTIDs per dimension for delayed and normal
    delayed_df = df[df['is_delayed']].groupby(dimension_cols)['mtid'].nunique().reset_index()
    delayed_df.columns = dimension_cols + ['delayed_mtids']
    
    normal_df = df[~df['is_delayed']].groupby(dimension_cols)['mtid'].nunique().reset_index()
    normal_df.columns = dimension_cols + ['normal_mtids']
    
    total_df = df.groupby(dimension_cols)['mtid'].nunique().reset_index()
    total_df.columns = dimension_cols + ['total_mtids']
    
    # Merge all
    result = total_df.merge(delayed_df, on=dimension_cols, how='left').merge(normal_df, on=dimension_cols, how='left')
    result = result.fillna(0)
    result['delayed_mtids'] = result['delayed_mtids'].astype(int)
    result['normal_mtids'] = result['normal_mtids'].astype(int)
    result['delayed_pct'] = (result['delayed_mtids'] / result['total_mtids'] * 100).round(1)
    
    return result

# By Exchange (top 30 by delayed_mtids, sorted by delayed_pct)
print(f"\n--- By Exchange (Top 30 by delayed_mtids, sorted by delayed_pct DESC) ---")
exchange_comparison = count_mtids_by_dimension(df_itct, 'exchange')
exchange_top30 = exchange_comparison.nlargest(30, 'delayed_mtids').sort_values('delayed_pct', ascending=False)
print(exchange_top30.to_string(index=False))

# By Publisher (top 30 by delayed_mtids, sorted by delayed_pct)
print(f"\n--- By Publisher (Top 30 by delayed_mtids, sorted by delayed_pct DESC) ---")
pub_comparison = count_mtids_by_dimension(df_itct, ['bundle', 'publisher_name'])
pub_top30 = pub_comparison.nlargest(30, 'delayed_mtids').sort_values('delayed_pct', ascending=False)
print(pub_top30.to_string(index=False))

# By IP (top 30 by delayed_mtids, sorted by delayed_pct)
print(f"\n--- By IP (Top 30 by delayed_mtids, sorted by delayed_pct DESC) ---")
ip_comparison = count_mtids_by_dimension(df_itct, 'ip')
ip_top30 = ip_comparison.nlargest(30, 'delayed_mtids').sort_values('delayed_pct', ascending=False)
print(ip_top30.to_string(index=False))

# IPs with 100% delayed MTIDs (all their MTIDs have delayed clicks)
print(f"\n--- IPs with 100% Delayed MTIDs (min 10 MTIDs) ---")
ip_100pct_delayed = ip_comparison[(ip_comparison['delayed_pct'] == 100) & (ip_comparison['total_mtids'] >= 10)]
ip_100pct_delayed = ip_100pct_delayed.sort_values('total_mtids', ascending=False)
print(f"Count: {len(ip_100pct_delayed)}")
if len(ip_100pct_delayed) > 0:
    print(ip_100pct_delayed.head(20).to_string(index=False))
# Out:
# ======================================================================
# Q3: Patterns in Highly Delayed Clicks (by distinct MTID)
# ======================================================================
#
# Delay Threshold: 150 seconds
# Total unique MTIDs: 183,465
# MTIDs with delayed clicks (>150s): 27,305 (14.9%)
# MTIDs with normal clicks: 151,524
# MTIDs with BOTH delayed & normal: 14,447
#
# --- By Exchange (Top 30 by delayed_mtids, sorted by delayed_pct DESC) ---
#                   exchange  total_mtids  delayed_mtids  normal_mtids  delayed_pct
#                    ADMIXER            2              2             0        100.0
#                        APS          441            318           134         72.1
#       MOLOCO_SDK_LEVELPLAY          234            143           181         61.1
#                   PUBMATIC          504            271           169         53.8
#             MOLOCO_SDK_MAX        28962          15062         24911         52.0
#                    EXELBID          325            117           229         36.0
#                     XIAOMI          572            126           265         22.0
#                      NAVER          110             23            83         20.9
#               ADGENERATION          488            101           427         20.7
#                      UNITY          191             34           169         17.8
#                     NIMBUS           22              3            20         13.6
#                   APPLOVIN        12041           1573         10156         13.1
#                     INMOBI        25719           3191         18939         12.4
#                    ADX_RTB          736             72           696          9.8
#                 IRONSOURCE          123             11            54          8.9
#                      ADPIE        25602           2235         23242          8.7
#                     VUNGLE         7238            568          4241          7.8
#                      KAKAO         9301            648          8473          7.0
#                      FYBER         5002            287          4604          5.7
#                    MOMENTO         6446            353          5929          5.5
#                    MANPLUS         2163            112          1986          5.2
# MOLOCO_SDK_ADMOB_MEDIATION         6930            361          6613          5.2
#                   APPODEAL        27800           1270         26444          4.6
#                        NHN         3718            128          3387          3.4
#                  ADPOPCORN        18788            296         10166          1.6
#           PRIVATE_SKT_ASUM            2              0             2          0.0
#                    TABOOLA            5              0             4          0.0
#
# --- By Publisher (Top 30 by delayed_mtids, sorted by delayed_pct DESC) ---
#                                      bundle               publisher_name  total_mtids  delayed_mtids  normal_mtids  delayed_pct
#         com.pixel.art.coloring.color.number                       X-Flow          524            496           414         94.7
#                com.easybrain.sudoku.android                    Easybrain          222            199           153         89.6
#                      com.yolo.hiddenobjects                   Yolo Games          247            220           214         89.1
#              easy.sudoku.puzzle.solver.free                OAKEVER_GAMES          451            400           330         88.7
#            com.easybrain.block.puzzle.games                    Easybrain          172            152           137         88.4
#                      com.ssaksri.gostopcity                NEPTUNE_AD(X)          364            318           286         87.4
#               sudoku.puzzle.free.game.brain                         Guru          336            289           284         86.0
#                             com.ig.screwdom                        IKAME          301            254           247         84.4
# solitaire.patience.card.games.klondike.free                         Guru          289            243           236         84.1
#             com.wood.block.sudoku.puzzle.bm             WONDERFUL TYCOON          443            363           371         81.9
#                            com.block.juggle                Hungry Studio         6775           5335          5600         78.7
#                      com.vitastudio.mahjong                OAKEVER_GAMES          915            653           741         71.4
#                                    com.ltlk                         MIBC          534            379           275         71.0
#                        com.oakever.tiletrip                OAKEVER_GAMES          552            315           469         57.1
#                linkdesks.merge.gossipstreet LinkDesks - Jewel Games Star          496            275           282         55.4
#                               cash.money.v1                                       313            148           193         47.3
#                                    com.ltlk                    MIBC Inc.         2222           1020          1147         45.9
#                          com.read.goodnovel                    GoodNovel          827            302           696         36.5
#                                    com.ltlk                                      2139            727          1825         34.0
#                                 me.timecash                                      1450            392          1028         27.0
#                            com.block.juggle                                       579            152           430         26.3
#                       com.cashwalk.cashwalk                                      1566            347          1062         22.2
#                   com.ilevit.alwayz.android                   Levit Inc.         9138            756          8312          8.3
#                    com.lottemembers.android      Lotte Members Co., Ltd.         2530            193          2299          7.6
#                         kr.bitbyte.moneypig       Delight Room Co., Ltd.         5099            368          4636          7.2
#                              com.kakao.talk                         TALK         3834            257          3504          6.7
#                          com.tracerofficial                  Gravity Ltd         9275            449          8824          4.8
#                       com.cashwalk.cashwalk               CashWalk, Inc.         3950            173          3358          4.4
#                            com.kakaopay.app                                      5282            191          4902          3.6
#              com.skmc.okcashbag.home_google                                      7195            151          6874          2.1
#
# --- By IP (Top 30 by delayed_mtids, sorted by delayed_pct DESC) ---
#              ip  total_mtids  delayed_mtids  normal_mtids  delayed_pct
#  121.185.11.134           63             53            21         84.1
#     14.52.3.170           88             71            51         80.7
#  211.118.79.153           61             47            14         77.0
# 112.153.214.251           35             26            25         74.3
#    61.77.147.64           31             23            26         74.2
# 220.126.114.178           42             30            22         71.4
#  220.118.43.250          301            211           131         70.1
#   183.108.12.86           33             23            26         69.7
#  121.179.89.173          100             67            79         67.0
#   220.76.99.215          450            296           238         65.8
#   61.98.225.230           52             33            31         63.5
# 112.157.109.130          145             87           102         60.0
#    118.91.86.88           46             26            43         56.5
#   58.145.79.165          246            138           220         56.1
# 211.222.130.204           40             22            22         55.0
# 119.194.164.169          130             61           105         46.9
#    118.235.4.64           59             27            47         45.8
# 116.127.138.157          111             50            87         45.0
#   218.157.57.82           83             37            61         44.6
# 221.162.213.166           48             20            27         41.7
#  125.138.12.170           98             39            65         39.8
#    124.59.25.32          116             43            90         37.1
#  211.214.225.55           74             26            53         35.1
#   58.237.87.168           75             21            50         28.0
# 183.100.124.209          174             48           133         27.6
#  182.209.228.12          264             61           256         23.1
#   119.201.66.68          128             25           100         19.5
#  116.32.215.139          157             25           133         15.9
#                         3379            326          1817          9.6
#    58.226.97.60          469             21           459          4.5
#
# --- IPs with 100% Delayed MTIDs (min 10 MTIDs) ---
# Count: 1
#              ip  total_mtids  delayed_mtids  normal_mtids  delayed_pct
# 211.185.211.140           12             12             0        100.0

# %%
#@title Step 3: ITCT Distribution Analysis

print("=" * 60)
print("ITCT (Impression to Click Time) Distribution")
print("=" * 60)

# Basic stats
print(f"\nITCT Statistics (in seconds):")
print(df_itct['itct_sec'].describe())

# Percentiles
print(f"\nITCT Percentiles (in seconds):")
percentiles = [0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99]
for p in percentiles:
    val = df_itct['itct_sec'].quantile(p)
    print(f"  P{int(p*100):02d}: {val:.2f} sec")

# ITCT buckets
print(f"\nITCT Distribution by Bucket:")
df_itct['itct_bucket'] = pd.cut(
    df_itct['itct_sec'], 
    bins=[-float('inf'), 0, 1, 5, 10, 30, 60, 300, float('inf')],
    labels=['<0s (invalid)', '0-1s', '1-5s', '5-10s', '10-30s', '30-60s', '1-5min', '>5min']
)
bucket_counts = df_itct['itct_bucket'].value_counts().sort_index()
bucket_prop = df_itct['itct_bucket'].value_counts(normalize=True).sort_index()
bucket_df = pd.DataFrame({'count': bucket_counts, 'proportion': bucket_prop})
bucket_df['proportion'] = bucket_df['proportion'].apply(lambda x: f"{x:.2%}")
print(bucket_df)
# Out:
# ============================================================
# ITCT (Impression to Click Time) Distribution
# ============================================================
#
# ITCT Statistics (in seconds):
# count         348702.0
# mean      14242.938888
# std      158515.619492
# min               -3.0
# 25%               12.0
# 50%               38.0
# 75%              167.0
# max          7727092.0
# Name: itct_sec, dtype: Float64
#
# ITCT Percentiles (in seconds):
#   P10: 3.00 sec
#   P25: 12.00 sec
#   P50: 38.00 sec
#   P75: 167.00 sec
#   P90: 10315.70 sec
#   P95: 32310.95 sec
#   P99: 298776.99 sec
#
# ITCT Distribution by Bucket:
# itct_bucket
# <0s (invalid)     5893
# 0-1s             13438
# 1-5s             35303
# 5-10s            22440
# 10-30s           73428
# 30-60s           57537
# 1-5min           69680
# >5min            70983
# Name: count, dtype: int64

# %%
#@title Step 4: IP Analysis - Click Volume by IP

print("=" * 60)
print("IP Analysis: Click Volume Distribution")
print("=" * 60)

# Clicks per IP
df_ip_clicks = df_itct.groupby('ip').agg({
    'mtid': 'count',  # total clicks
    'ifa': 'nunique',  # unique IFAs
    'itct_sec': ['mean', 'median', 'std']
}).reset_index()
df_ip_clicks.columns = ['ip', 'click_count', 'unique_ifas', 'avg_itct_sec', 'median_itct_sec', 'std_itct_sec']
df_ip_clicks = df_ip_clicks.sort_values('click_count', ascending=False)

print(f"\nTotal unique IPs: {len(df_ip_clicks)}")
print(f"\nTop 20 IPs by click count:")
print(df_ip_clicks.head(20).to_string(index=False))

# IP concentration
total_clicks = df_ip_clicks['click_count'].sum()
df_ip_clicks['cumulative_pct'] = df_ip_clicks['click_count'].cumsum() / total_clicks * 100

print(f"\nIP Concentration:")
for threshold in [50, 70, 80, 90, 95]:
    num_ips = (df_ip_clicks['cumulative_pct'] <= threshold).sum() + 1
    print(f"  {threshold}% of clicks from top {num_ips} IPs ({num_ips/len(df_ip_clicks)*100:.1f}% of all IPs)")
# Out:
# ============================================================
# IP Analysis: Click Volume Distribution
# ============================================================
#
# Total unique IPs: 80106
#
# Top 20 IPs by click count:
#              ip  click_count  unique_ifas  avg_itct_sec  median_itct_sec   std_itct_sec
#   220.76.99.215        20464           26  76392.979986          28616.0  160587.258606
#     14.52.3.170         8160            7  73697.226498          22107.0  141528.145034
#                         8034         2369   25922.42444             13.0  390309.336372
#  220.118.43.250         5896           15  126186.42027          30020.0  229467.920331
#   58.145.79.165         2433            1    282.120253            152.0     355.347561
#   211.62.59.161         2104          717     11.306905              3.0       27.92835
#   211.62.59.166         1985          739     65.371658              3.0     614.614859
#   211.62.59.163         1982          703     27.631854              3.0     208.327566
#   211.62.59.165         1978          753     20.735556              3.0     117.363364
#   211.62.59.164         1922          698     13.172973              3.0      71.015646
#   211.62.59.160         1920          715    203.154964              3.0    3823.106341
#   211.62.59.162         1864          669      62.02439              2.0     708.569005
#   211.62.59.173         1855          723     33.015789              3.0     182.133239
#    58.226.97.60         1611           10    740.198992            102.0    4132.270702
#  182.209.228.12         1203           37    130.286428             74.0      174.09841
# 112.157.109.130         1018            1    601.443781            427.0     567.261311
#   211.62.59.143          998          409    136.544186              3.0    1261.573853
#   211.62.59.145          965          422    180.164103              3.0    1638.124995
#   211.62.59.144          916          405       5.54878              2.0      10.825048
# 116.127.138.157          545            1    197.641949             68.5     384.670191
#
# IP Concentration:
#   50% of clicks from top 6903 IPs (8.6% of all IPs)
#   70% of clicks from top 20133 IPs (25.1% of all IPs)
#   80% of clicks from top 28956 IPs (36.1% of all IPs)
#   90% of clicks from top 44850 IPs (56.0% of all IPs)
#   95% of clicks from top 60707 IPs (75.8% of all IPs)

# %%
#@title Step 5: Suspicious IP Patterns - High Click Count + Low ITCT

print("=" * 60)
print("Suspicious IP Patterns")
print("=" * 60)

# Flag suspicious IPs: high click count AND low average ITCT
CLICK_THRESHOLD = 50
ITCT_THRESHOLD = 5  # seconds

df_suspicious_ips = df_ip_clicks[
    (df_ip_clicks['click_count'] >= CLICK_THRESHOLD) & 
    (df_ip_clicks['avg_itct_sec'] <= ITCT_THRESHOLD)
].copy()

print(f"\nSuspicious IPs (>={CLICK_THRESHOLD} clicks AND avg ITCT <={ITCT_THRESHOLD}s):")
print(f"Count: {len(df_suspicious_ips)}")
if len(df_suspicious_ips) > 0:
    print(df_suspicious_ips.to_string(index=False))
    
    # What % of total clicks come from suspicious IPs?
    suspicious_clicks = df_suspicious_ips['click_count'].sum()
    print(f"\nSuspicious IP contribution:")
    print(f"  Clicks from suspicious IPs: {suspicious_clicks:,} ({suspicious_clicks/total_clicks*100:.1f}%)")
# Out:
# ============================================================
# Suspicious IP Patterns
# ============================================================
#
# Suspicious IPs (>=50 clicks AND avg ITCT <=5s):
# Count: 18
#              ip  click_count  unique_ifas  avg_itct_sec  median_itct_sec  std_itct_sec  cumulative_pct
#   112.170.97.57          152            2      4.591837              4.0      6.691597       19.687722
#   1.232.170.131          122            1      2.322314              1.0      5.834116       19.951648
#   112.151.4.162          120            1       2.87395              3.0      1.866541       20.013763
# 211.237.100.102          117            1      3.401709              1.0     12.447171       20.043919
#    59.12.88.155          103            1      3.621359              2.0      7.352626       20.240574
#   115.140.57.11          102            1      4.931373              2.0      7.070031       20.293153
#   125.189.76.35           99            2      2.363636              2.0      1.854143       20.397538
#   211.62.59.167           94           59      2.045455              1.5      1.463111       20.523057
#   221.153.205.2           88            1         2.375              2.0       2.35041       20.685691
# 118.216.101.245           82            1        2.5625              2.0      3.228997       20.922039
#   103.234.6.103           77            1      3.311688              1.0      5.417466       21.225914
# 211.234.202.203           68            1      2.484848              1.0      6.707613       21.710208
#  183.108.60.133           65            1      3.517857              3.0      2.821934       21.916399
#   58.123.48.101           60            1      2.633333              2.0       2.76765       22.288060
# 121.129.171.111           60            1      4.491525              2.0      7.874824       22.303525
#   211.235.99.24           55            1      3.181818              3.0      1.711518       22.837562
#  106.101.72.138           54            2      3.055556              2.0      2.673537       22.865656
#  114.206.248.89           53            1      3.576923              2.0      6.101579       23.045043
#
# Suspicious IP contribution:
#   Clicks from suspicious IPs: 1,571 (0.4%)

# %%
#@title Step 6: Clicks per MTID by IP

print("=" * 60)
print("Clicks per MTID Analysis by IP")
print("=" * 60)

# How many clicks per MTID, grouped by IP
df_mtid_clicks = df_itct.groupby(['ip', 'mtid']).agg({
    'click_timestamp': 'count',
    'itct_sec': 'mean'
}).reset_index()
df_mtid_clicks.columns = ['ip', 'mtid', 'clicks_per_mtid', 'avg_itct_sec']

# Aggregate to IP level: avg clicks per MTID
df_ip_mtid_pattern = df_mtid_clicks.groupby('ip').agg({
    'mtid': 'count',  # unique MTIDs
    'clicks_per_mtid': ['mean', 'max'],
    'avg_itct_sec': 'mean'
}).reset_index()
df_ip_mtid_pattern.columns = ['ip', 'unique_mtids', 'avg_clicks_per_mtid', 'max_clicks_per_mtid', 'avg_itct_sec']
df_ip_mtid_pattern = df_ip_mtid_pattern.sort_values('avg_clicks_per_mtid', ascending=False)

print(f"\nTop 20 IPs by avg clicks per MTID:")
print(df_ip_mtid_pattern.head(20).to_string(index=False))

# Flag IPs with abnormally high clicks per MTID
MTID_CLICK_THRESHOLD = 10
df_abnormal_ips = df_ip_mtid_pattern[df_ip_mtid_pattern['avg_clicks_per_mtid'] >= MTID_CLICK_THRESHOLD]
print(f"\nIPs with avg >={MTID_CLICK_THRESHOLD} clicks per MTID: {len(df_abnormal_ips)}")
# Out:
# ============================================================
# Clicks per MTID Analysis by IP
# ============================================================
#
# Top 20 IPs by avg clicks per MTID:
#              ip  unique_mtids  avg_clicks_per_mtid  max_clicks_per_mtid    avg_itct_sec
#   59.16.130.110             1           269.000000                  269     2962.672862
#   112.151.4.162             1           120.000000                  120         2.87395
#  220.85.185.187             4           104.000000                  179   191699.999102
#     14.52.3.170            88            92.727273                  853    83466.268158
#   1.254.164.227             1            79.000000                   79    33226.974684
# 121.181.112.129             1            76.000000                   76     8801.144737
#  58.141.235.170             1            71.000000                   71  5438861.239437
#    123.99.67.38             1            64.000000                   64            <NA>
#    222.236.3.33             1            62.000000                   62    22081.483871
#   115.138.62.15             1            59.000000                   59       76.559322
#   61.105.246.25             1            59.000000                   59      135.152542
#  211.234.226.82             1            59.000000                   59       82.050847
# 112.169.228.224             1            55.000000                   55    28146.981818
# 125.246.145.103             1            53.000000                   53      102.150943
#   180.70.14.108             1            50.000000                   50      1024154.92
#    180.67.25.58             1            47.000000                   47       69.680851
#   220.76.99.215           450            45.475556                  903    31835.470101
#  49.143.147.104             1            44.000000                   44      210.590909
#   1.253.194.102             5            43.400000                  197       321.39797
#    59.16.220.80             1            43.000000                   43       28.627907
#
# IPs with avg >=10 clicks per MTID: 797

# %%
#@title Step 7: Publisher + IP Cross Analysis

print("=" * 60)
print("Publisher + IP Cross Analysis")
print("=" * 60)

# Clicks by publisher and IP
df_pub_ip = df_itct.groupby(['bundle', 'publisher_name', 'ip']).agg({
    'mtid': 'count',
    'ifa': 'nunique',
    'itct_sec': 'mean'
}).reset_index()
df_pub_ip.columns = ['bundle', 'publisher_name', 'ip', 'click_count', 'unique_ifas', 'avg_itct_sec']
df_pub_ip = df_pub_ip.sort_values('click_count', ascending=False)

print(f"\nTop 30 Publisher + IP combinations:")
print(df_pub_ip.head(30).to_string(index=False))

# Publishers with concentrated IP patterns
df_pub_ip_concentration = df_itct.groupby('bundle').agg({
    'ip': 'nunique',
    'mtid': 'count'
}).reset_index()
df_pub_ip_concentration.columns = ['bundle', 'unique_ips', 'total_clicks']
df_pub_ip_concentration['clicks_per_ip'] = df_pub_ip_concentration['total_clicks'] / df_pub_ip_concentration['unique_ips']
df_pub_ip_concentration = df_pub_ip_concentration.sort_values('clicks_per_ip', ascending=False)

print(f"\nPublishers by clicks per unique IP:")
print(df_pub_ip_concentration.to_string(index=False))
# Out:
# ============================================================
# Publisher + IP Cross Analysis
# ============================================================
#
# Top 30 Publisher + IP combinations:
#                    bundle         publisher_name              ip  click_count  unique_ifas   avg_itct_sec
#           me.cash.time.v3                          220.76.99.215         6919           18   63925.584804
#               me.timecash                            14.52.3.170         5474            6   65124.749726
#               me.timecash                          220.76.99.215         5191           20   74796.567899
#             cash.money.v1                          220.76.99.215         4135           21   86539.143168
#               me.timecash                         220.118.43.250         2672           12   55399.017623
#             com.cashslide Delight Room Co., Ltd.                         2268          519    1457.590909
#           net.cashplus.b3                          220.76.99.215         1771           16   44445.018089
#                  com.ltlk                          58.145.79.165         1431            1     329.781206
#  com.lottemembers.android                          211.62.59.161         1377          269           <NA>
#           net.cashplus.b3                         220.118.43.250         1355            7   79016.252457
#  com.lottemembers.android                          211.62.59.163         1268          248           <NA>
#  com.lottemembers.android                          211.62.59.166         1238          267           <NA>
#  com.lottemembers.android                          211.62.59.165         1204          274           <NA>
#  com.lottemembers.android                          211.62.59.160         1196          248           <NA>
#  com.lottemembers.android                          211.62.59.164         1190          257           <NA>
#  com.lottemembers.android                          211.62.59.162         1173          235           <NA>
#  com.lottemembers.android                          211.62.59.173         1168          271           <NA>
#             cash.money.v1                            14.52.3.170         1123            5   133088.42246
#               me.timecash                  adlib   220.76.99.215          918           11  140825.833333
#                  com.ltlk                        112.157.109.130          846            1     656.940898
# everyclick.lusoft.android Delight Room Co., Ltd.  182.209.228.12          730           27     151.353022
#  com.lottemembers.android                          211.62.59.143          649          167           <NA>
# everyclick.lusoft.android Delight Room Co., Ltd.    58.226.97.60          610            7     128.491803
#  com.lottemembers.android                          211.62.59.145          609          172           <NA>
#  com.lottemembers.android                          211.62.59.144          596          174           <NA>
# com.dencreak.dlcalculator           Cleveni Inc.                          593          111    1728.780776
#           net.cashplus.b3                ANYTALE  220.118.43.250          532            3  696542.951128
#                  com.ltlk                   MIBC   58.145.79.165          520            1     271.976923
#           net.cashplus.b3                ANYTALE   220.76.99.215          518            5  222405.069498
#             cash.money.v1                ANYTALE   220.76.99.215          515            7   74575.926214
#
# Publishers by clicks per unique IP:
#                                                                                                  bundle  unique_ips  total_clicks  clicks_per_ip
#                                                                                     com.happy.happywalk           2           161      80.500000
#                                                                        com.joyfulark.coloring.christmas           1            64      64.000000
#                                                                                         me.cash.time.v3         144          8957      62.201389
#                                                                                           cash.money.v1         126          7039      55.865079
#                                                                                    com.ig.hole.eats.all           1            42      42.000000
#                                                                                 com.ovivo.pizza.perfect           2            70      35.000000
#                                                                               com.happygames.mergehotel           4           136      34.000000
#                                                           com.openmygame.games.android.fillwordsoffline           4           128      32.000000
#                                                                                   com.gimica.ballbounce           1            29      29.000000
#                                                                                    com.puzzle.mergecard           1            29      29.000000
#                                                                                com.bngame.app.woodblock           1            27      27.000000
#                                                                               com.freerange360.mpp.GOAL           1            25      25.000000
#                                                                          com.beauty.merge.love.makeover           1            24      24.000000
#                                                                                  com.puzzle.merge.games           3            64      21.333333
#                                                                                  com.superbox.aos.merge           1            21      21.000000
#                                                                  com.balloon.triple.match.master3d.game           1            21      21.000000
#                                                                               everyclick.lusoft.android         143          2904      20.307692
#                                                                              com.vinetree.gametalktalk2           2            39      19.500000
#                                                                               com.warmhearts.rocktoyou2          30           571      19.033333
#                                                                                           tunein.player           1            19      19.000000
#                                                                                  com.PYOPYO.StarTracker           1            18      18.000000
#                                                                  com.bricksbreaker.balls.crusher.bricks           2            36      18.000000
#                                                                                  com.xentech.brickblast           3            52      17.333333
#                                                                                            com.th.chemi           1            17      17.000000
#                                                                                      com.mobirix.mobigo           2            33      16.500000
#                                                                                             me.timecash        1063         17036      16.026341
#                                                                             com.inspiredsquare.jupiter1           2            32      16.000000
#                                                                                  com.hg.happydessertsKR           3            46      15.333333
#                                                     qrcodescanner.barcodescanner.qrscanner.qrcodereader           1            15      15.000000
#                                                                                         net.cashplus.b3         384          5426      14.130208
#                                                                                      com.mkg.bloomgoods           2            28      14.000000
#                                                                                      com.kayac.ball_run           2            28      14.000000
#                                                                                 com.ftt.samblade.kr.aos           1            14      14.000000
#                                                                             com.tile.match.connect.game           2            27      13.500000
#                                                                                com.carrytheworld.donchu           5            66      13.200000
#                                                                                         com.cyberjoy.x3           1            13      13.000000
#                                                                                com.manababa.BeggarLife3           2            26      13.000000
#                          com.old.play.musicplayer.descargar.baixar.mp3.music.downloader.gratis.original           1            13      13.000000
#                                                                          match3d.games.free.ball.bubble           1            13      13.000000
#                                                                                                com.ltlk        1179         15136      12.837998
#                                                                                 com.tatemgames.dreamgym           3            38      12.666667
#                                                                 linkdesks.pop.bubblegames.bubbleshooter           1            12      12.000000
#                                                                              com.unicostudio.smashblock           1            12      12.000000
#                                                                               com.cashwalklabs.cashwalk           1            12      12.000000
#                                                                photoeditor.piccollage.grid.collagemaker           1            12      12.000000
#                                                                              com.ksenastranger.trichess           1            12      12.000000
#                                                  com.solitaire.fun.free.klondike.cardgames.farm.friends           1            12      12.000000
#                                                             com.lyoomatch.jewelscrush.princessadventure           1            12      12.000000
#                                                                             com.cardgame.solitaire.full           2            23      11.500000
#                                                           jp.co.goodroid.hyper.puzzle.colorblockbuilder           1            11      11.000000
#                                                                  com.supermarket.manager.simulator.game           1            11      11.000000
#                                                                     com.corestudios.storemanagementidle           2            22      11.000000
#                                                     jigsaw.puzzle.color.master.paint.classical.hd.funny           1            11      11.000000
#                                                                                    com.gimica.bubblepop           1            11      11.000000
#                                                                               com.superbox.aos.boltGame          10           110      11.000000
#                                                                            com.easybrain.nonogram.color           1            11      11.000000
#                                                                          com.mrproject.game.storm.screw           1            11      11.000000
#                                                                   tile.triple.match.puzzle.game.journey           1            11      11.000000
#                                                                                  com.bytetyper.gemstack           1            11      11.000000
#                                                                               com.ibragunduz.applockpro           2            21      10.500000
#                                                                         com.unicostudio.farmblockescape           2            20      10.000000
#                                                            com.FeliceCasaTechnologyPTE.LTD.WaterSortPro           1            10      10.000000
#                                                                                        net.wordbit.frkr           1            10      10.000000
#                                                                                      com.iu.armypioneer           1            10      10.000000
#                                                                                       com.radio.fmradio           1            10      10.000000
#                                                                                        jcsla.randomtalk           1            10      10.000000
#                                                                                           wongi.weather           1            10      10.000000
#                                                                                  com.master.hotelmaster          10            98       9.800000
#                                                                        com.easybrain.killer.sudoku.free          34           325       9.558824
#                                                                                   com.mingle.dateinasia           2            19       9.500000
#                                                                           com.stellajoy.jigsawsolitaire          13           121       9.307692
#                                                                                          com.gwangbuapp          14           130       9.285714
#                                                                                com.skgames.trafficrider           1             9       9.000000
#                                                           solitaire.classic.klondike.patience.card.game           9            81       9.000000
#                                                                                 com.matchington.mansion           7            63       9.000000
#                                                                           com.unicostudio.hiddenobjects           1             9       9.000000
#                                                                                       kr.encom.gostop_p           1             9       9.000000
#                                                             com.matching.games.goods.sort.triple.puzzle           1             9       9.000000
#                                                                    ttg.woodscrew.puzzle.wood.nuts.bolts           1             9       9.000000
#                                                                                   com.ig.royalty.puzzle           3            26       8.666667
#                                                                              com.alpaca.android.readout           3            26       8.666667
#                                                                                  io.supercent.weaponrpg          19           163       8.578947
#                                                                                  com.ssaksri.gostopcity         305          2611       8.560656
#                                                                            wool.sort.jam.color.painting           4            34       8.500000
#                                                                                        com.samsung.sree           7            59       8.428571
#                                                                                 com.reviewtube.pigmoney          36           294       8.166667
#                                                                              com.ssaksri.freegostopplus         130          1041       8.007692
#                                                                               com.hookah.sandboxinspace           6            48       8.000000
#                                                                                  com.tapempire.wordgame           2            16       8.000000
#                                                                    com.brain.jewel.block.Dropdom.puzzle           1             8       8.000000
#                                                             com.FelicityGames.NutSortColorSortingPuzzle           4            32       8.000000
#                                                                           com.traffic.jam.rumble.escape           1             8       8.000000
#                                                                         com.dalakgames.pixeldestruction           2            16       8.000000
#                                                                                            com.eco.note           3            24       8.000000
#                                                                                   com.easyfun.solitaire           1             8       8.000000
#                                                                             studio.gameberry.idlehunter           1             8       8.000000
#                                                                             com.madfingergames.unkilled           1             8       8.000000
#                                                                               com.dencreak.dlcalculator         249          1965       7.891566
#                                                                            block.escape.tap.away.puzzle           3            23       7.666667
#                                                              atlantis.invaders.subnautica.space.shooter           3            23       7.666667
#                                                                              com.olleyo.piggy.king.free          18           137       7.611111
#                                                                                           com.cashslide         782          5870       7.506394
#                                                                              com.dragon.water.sort.saga           2            15       7.500000
#                                                                       com.blockpuzzle.classicbrickgames           2            15       7.500000
#                                                                          com.match3d.triple.sort.puzzle           4            30       7.500000
#                                                                             com.komorebi.SimpleCalendar           2            15       7.500000
#                                                                      com.appguruz.sherlock.mysterymerge           2            15       7.500000
#                                                                   jp.co.goodroid.hyper.nutsandboltssort           2            15       7.500000
#                                                                            linkdesks.merge.gossipstreet         102           762       7.470588
#                                                                             com.mergedomhomedesign.game          62           463       7.467742
#                                                                                com.IdleMagicSchool.jlyt          12            88       7.333333
#                                                                                   com.hanaskcard.paycla         349          2533       7.257880
#                                                               com.solitaire.fish.klondike.card.aquarium          12            87       7.250000
#                                                                 com.sweet.candy.journey.match.puzzle.gp           4            29       7.250000
#                                                                           com.superbox.aos.jewelsjungle          23           165       7.173913
#                                                                         com.eight.ball.strike.challenge          13            93       7.153846
#                                                                                     com.LoopGames.Blast           1             7       7.000000
#                                                                              com.mkunggefru.merge.maker           2            14       7.000000
#                                                                   com.hexa.sort.puzzle.stack.color.game           3            21       7.000000
#                                                                       com.theguligames.landsofadventure           2            14       7.000000
#                                                                                 com.RayGaming.CandyGrab           5            35       7.000000
#                                                                                  com.tapped.snipersiege           1             7       7.000000
#                                                                             com.superbox.aos.spookizpop           1             7       7.000000
#                                                                          step.counter.tracker.pedometer           1             7       7.000000
#                                                                     com.primitivebrother.thunder.google           2            14       7.000000
#                                                                                    com.numberpaint.game           1             7       7.000000
#                                                                                  com.oakever.jigsawcard           4            28       7.000000
#                                                                                  com.yodo1.rodeo.safari           1             7       7.000000
#                                                                                   com.niklas.fpsdefense           2            14       7.000000
#                                                                                        com.maf.projectH           1             7       7.000000
#                                                                                  com.cardgame.solitaire           2            14       7.000000
#                                                                                 com.playvalve.watersort           1             7       7.000000
#                                                                            com.countystory.mergecooking           1             7       7.000000
#                                                                                   com.game.gs3d_android           3            21       7.000000
#                                                                                 com.sp.slide.block.rush           2            14       7.000000
#                                                                                        com.puzzle.merge           1             7       7.000000
#                                                                       com.card.battle.queen.duel.pretty           2            14       7.000000
#                                                                                       com.bbumgames.opa           1             7       7.000000
#                                                                                     com.dencreak.spbook          86           585       6.802326
#                                                                     spot.hidden.cat.find.hidden.objects           8            54       6.750000
#                                                                                  com.nebula.blockpuzzle           4            27       6.750000
#                                                                                      io.whitesharx.moon           4            27       6.750000
#                                                                                             today.chips          10            67       6.700000
#                                                                      com.goods.free.puzzle.match3d.sort         105           701       6.676190
#                                                                                     com.dencreak.esmemo          78           520       6.666667
#                                                                       musicplayer.playmusic.audioplayer           5            33       6.600000
#                                                                                      com.play.tileverse           5            33       6.600000
#                                                                         screw.pin.out.sort.puzzle.games           5            33       6.600000
#                                                                                            com.braindom           5            33       6.600000
#                                                                                    kr.co.doohub.cashrun           2            13       6.500000
#                                                                             com.ncroquis.freegostop2021           4            26       6.500000
#                                                                         com.medherapps.game.gem.jam.out           2            13       6.500000
#                                                                                com.go7game.jewelclassic           2            13       6.500000
#                                                                                       screw.jam.handler           4            26       6.500000
#                                                                       animal.connect.relax.match.puzzle          25           160       6.400000
#                                                            jigsolitaire.jigsort.jigsaw.solitaire.puzzle           4            25       6.250000
#                                                                                   com.changdu.mobovideo           4            25       6.250000
#                                                                       com.fantile.sliding.dragon.puzzle           8            50       6.250000
#                                                                          com.adr.dgda.game.style.secret           4            25       6.250000
#                                                                                     com.magicgs.seatjam           4            25       6.250000
#                                                                                       com.OrderUp.merge          29           181       6.241379
#                                                                                    com.u3.ixdg.yarn.out          19           118       6.210526
#                                                                           com.mahjong.match.pair.puzzle           5            31       6.200000
#                                                                                      com.read.goodnovel         578          3572       6.179931
#                                                                                com.chefmerge.room.decor          19           117       6.157895
#                                                                                        com.mobirix.ldwm          24           147       6.125000
#                                                                               com.braingames.findthedog          28           171       6.107143
#                                                            com.gamee.kingdom.royale.match3.blast.escape          10            61       6.100000
#                                                                                com.lottemembers.android        3317         19906       6.001206
#                                                                     com.bible.holybible.nkjv.dailyverse           1             6       6.000000
#                                                                    com.leonet.deluxe.block.jewel.puzzle           2            12       6.000000
#                                                                                   onetap.game.good.sort          11            66       6.000000
#                                                                                  com.playvalve.ballsort           1             6       6.000000
#                                                                        heigou.flygame.goodsstory.puzzle           2            12       6.000000
#                                            solitaire.tripeaks.farm.free.card.games.grand.harvest.garden           1             6       6.000000
#                                                                com.zymobile.merge.master.home.design.gp           2            12       6.000000
#                                                                                         com.dubox.drive           6            36       6.000000
#                                                                                     com.wave.carvequest           1             6       6.000000
#                                                           com.kiwifun.game.android.numbermaster.puzzles           4            24       6.000000
#                                                                              com.wireless.airportmaster           1             6       6.000000
#                                                                                         com.bluecat.yut           1             6       6.000000
#                                                                         ball.sort.color.puz.game.puzzle           5            30       6.000000
#                                                                               com.linecorp.b612.android           1             6       6.000000
#                                                                                          kr.co.lives.ls           1             6       6.000000
#                                                                                com.mobirix.mahjongking2           2            12       6.000000
#                                                                                 bubble.shooter.exxtreme           1             6       6.000000
#                                                                        com.mart.goods.sort.match.triple           3            18       6.000000
#                                                                              com.yarndom.unravel.puzzle           1             6       6.000000
#                                                                            com.ynsgames.aos.jewelsocean           1             6       6.000000
#                                                                             com.neowiz.games.gostop2018           1             6       6.000000
#                                                                             com.dreamcups.voicerecorder           2            12       6.000000
#                                                                                 kr.co.thecheat.thecheat           2            12       6.000000
#                                                                           com.unravel.yarn.screw.puzzle           1             6       6.000000
#                                  tienlen.poker.card.game.online.offline.multiplayer.samloc.miennam.free           1             6       6.000000
#                                                                           com.MoodGames.TrafficJamFever           1             6       6.000000
#                                                                     com.shoreline.game.spider.solitaire           1             6       6.000000
#                                                                                        io.voodoo.holeio          13            77       5.923077
#                                                            com.space.shooter.galaxy.attack.wing.fighter          25           148       5.920000
#                                                                        com.game.mayablockpuzzle_android          12            71       5.916667
#                                                                         com.actionfit.merge.supermarket          43           252       5.860465
#                                                                              com.tripledot.tiles.mosaic           7            41       5.857143
#                                                                                        com.zm.watersort          35           205       5.857143
#                                                                                          im.bigc.lively           5            29       5.800000
#                                                                  com.tripleclick.tile.block.puzzle.game           5            29       5.800000
#                                                                classic.relax.happy.color.by.number.game          28           162       5.785714
#                                                                                     viva.republica.toss         134           773       5.768657
#                                                        nuts.sort.bolts.nut.color.game.free.screw.puzzle           4            23       5.750000
#                                                              blockpuzzle.new1010.jewelgames.puzzlegames          36           207       5.750000
#                                                                          onet.tile.match.puzzle.android          75           431       5.746667
#                                                                                     com.hw.gecko.escape          15            86       5.733333
#                                                                                com.bugbomb.dumptruckjam          12            68       5.666667
#                                                                   merge.blocks.drop.number.puzzle.games           9            51       5.666667
#                                                                           com.mlmj.sort.tidy.puzzle.ddd           3            17       5.666667
#                                                                                       com.productmkf.dn          12            68       5.666667
#                                                                  com.spot.find.differences.brain.puzzle           3            17       5.666667
#                                                                             com.quick.flicks.drama.lite           3            17       5.666667
#                                                                                            com.dig.deep           3            17       5.666667
#                                                                          easy.sudoku.puzzle.solver.free         432          2418       5.597222
#                                                                                 com.vincentb.MobControl          69           386       5.594203
#                                                                                  com.goodville.goodgame          17            94       5.529412
#                                                           com.pin.screw.color.nuts.bolts.spin.free.game         102           563       5.519608
#                                                         com.hidden.object.find.beauty.search.games.free           6            33       5.500000
#                                                                              com.matchinggo.puzzlegames           2            11       5.500000
#                                                                        nut.sort.puzzle.color.game.magic           2            11       5.500000
#                                                              traffic.car.jam.escape.parking.puzzle.race          12            66       5.500000
#                                                                                       hexa.sort.journey           2            11       5.500000
#                                                                                               my.geulga           2            11       5.500000
#                                                                           com.stickyhands.mergesurvival           2            11       5.500000
#                                                                        com.easybrain.number.sums.puzzle          25           137       5.480000
#                                                                               jigsaw.puzzle.game.banana         128           694       5.421875
#                                                                                and.lihuhu.blossommaster           5            27       5.400000
#                                                                                 com.gretech.gomplayerko           5            27       5.400000
#                                                                              com.superhit.aos.screwwood          16            86       5.375000
#                                                                       com.easybrain.find.the.difference          17            91       5.352941
#                                                                                 com.ovivo.waffle.puffle           3            16       5.333333
#                                                                                 com.mobirix.swipebrick2          18            96       5.333333
#                                                                             com.sniper.shooter.wild.ssw           3            16       5.333333
#                                                                                               com.lotte           3            16       5.333333
#                                                                          block.jam.color.puzzle3d.slide           3            16       5.333333
#                                                                                  linkdesks.fashionmatch           3            16       5.333333
#                                                         math.puzzle.games.crossmath.number.puzzles.free         150           799       5.326667
#                                                                               com.superbox.aos.jewelsuc         373          1962       5.260054
#                                                                     com.easystudio.screw.pin.jam.puzzle           4            21       5.250000
#                                                                 com.linkdesks.bubblegames.bubbleshooter           4            21       5.250000
#                                                                              com.superbox.aos.meowblock           4            21       5.250000
#                                                                                       kr.co.tf.starwars           4            21       5.250000
#                                     in.playsimple.triple.tile.matchgame.pair.three.puzzle.object.royale          52           273       5.250000
# com.arumgames.cat.animal.pet.idle.clicker.tycoon.hypercasual.simulation.snackbar.restaurant.eat.venture          43           225       5.232558
#                                                                     com.pixel.art.coloring.color.number         541          2829       5.229205
#                                                                            com.screenshake.dominodreams          19            99       5.210526
#                                                           com.goods.sorting.games.triple.match3d.puzzle          20           104       5.200000
#                                                                        com.pocket.sort.coin.puzzle.game          62           321       5.177419
#                                              com.find.hidden.object.out.treasure.hunt.seek.puzzle.games           6            31       5.166667
#                                                                          com.superbox.aos.hamsterTycoon         266          1366       5.135338
#                                                                 com.color.page.paint.pixel.number.happy           8            41       5.125000
#                                                                                jigsaw.puzzle.free.games          72           369       5.125000
#                                                      com.blockblast.adventuremaster.blockpuzzle.samsung          28           143       5.107143
#                                                                               com.ssaksri.no1freegostop          10            51       5.100000
#                                                                          com.ohtegames.reward.solitaire          56           285       5.089286
#                                                                                com.tatemgames.watersort          16            81       5.062500
#                                                                                 com.king.candycrushsaga          81           410       5.061728
#                                                                       com.sundaytoz.kakao.matgo.service         122           615       5.040984
#                                                                               com.littledinosaur.bunnys          27           136       5.037037
#                                                                              com.easybrain.hidden.spots          44           221       5.022727
#                                                                       com.bid.master.war.auction.battle          48           241       5.020833
#                                                             solitaire.patience.card.games.klondike.free         272          1361       5.003676
#                                                      com.fairy.tale.happy.paint.by.number.coloring.game           1             5       5.000000
#                                                        com.find.spot.photo.hunt.differences.free.hidden           2            10       5.000000
#                                                                     com.braingames.hollywoodtriplematch           1             5       5.000000
#                                                          com.fc.p.wj.cozy.kitchen.relaxing.cooking.asmr           1             5       5.000000
#                                                                                  com.meitu.meiyancamera           1             5       5.000000
#                                                                             eu.livesport.FlashScore_com           4            20       5.000000
#                                                                            io.superbrick.minimartmaster           2            10       5.000000
#                                                                         killer.sudoku.free.brain.puzzle           5            25       5.000000
#                                                                            io.superbrick.masterhospital           1             5       5.000000
#                                                                                      com.car.jam.puzzle           5            25       5.000000
#                                                                            com.fc.block.out.wood.puzzle           1             5       5.000000
#                                                                                com.hinam.khmer.keyboard           1             5       5.000000
#                                                                                com.capybara.idle.office           1             5       5.000000
#                                                 com.mandala.pattern.happy.paint.by.number.coloring.game           1             5       5.000000
#                                                                                    fg.nuts.sort.journey           6            30       5.000000
#                                                                                  com.marinaprotocol.app           1             5       5.000000
#                                                                com.matchingham.flashback.tricky.riddles           1             5       5.000000
#                                                                               com.bubble.shooter.family           1             5       5.000000
#                                                                                   com.maroieqrwlk.unpin           1             5       5.000000
#                                                                           com.match.mahjong.pair.puzzle           1             5       5.000000
#                                                                                  com.higgs.tilemaster3d           1             5       5.000000
#                                                                    com.flower.puzzle.blossom.sort.color           1             5       5.000000
#                                                                                           com.hide.ball           2            10       5.000000
#                                                                                       com.daseetv.watch           1             5       5.000000
#                                                                                 com.formulacash.android           1             5       5.000000
#                                                                         com.funnyapp_corp.game.gostopjc           1             5       5.000000
#                                                                                 fancy.jigsaw.art.puzzle           1             5       5.000000
#                                                                                com.fishsort.puzzle.game           1             5       5.000000
#                                                                                 com.dots.connect.puzzle           1             5       5.000000
#                                                                                   match.tap3tile.talent           1             5       5.000000
#                                                                        gridplus.bubblerelax.pop.shooter           2            10       5.000000
#                                                                                         com.cle.yulgang           2            10       5.000000
#                                                                                games.tatsumaki.snowrush           2            10       5.000000
#                                                                                games.urmobi.find.it.all           1             5       5.000000
#                                                                              com.cocoplay.fashion.style           1             5       5.000000
#                                                                                     com.ken.supermarket           1             5       5.000000
#                                                                                     com.color.block.jam           2            10       5.000000
#                                                                com.gt.moto.bike.wheelie.stunt.race.game           1             5       5.000000
#                                                                                     com.kayac.DrawFight           1             5       5.000000
# ...
#                                                                                          com.joycity.gw           1             1       1.000000
#                                                                                 com.ig.color.wood.screw           1             1       1.000000
#                                                                            com.iceors.colorbook.release           1             1       1.000000
#                                                                                  com.hybridparking.game           1             1       1.000000
#                                                                               com.hw.pixel.shoot.master           1             1       1.000000
#                                                                                   com.htbeyond.bybeyond           1             1       1.000000
#                                                                                  com.honeyponey.catjump           1             1       1.000000
#                                                                                           com.hole.drop           1             1       1.000000
#                                                                                         com.hobby2.talk           1             1       1.000000
#                                                                                   com.hitapps.figgerits           1             1       1.000000
#                                                                                  com.higgs.cubemaster3d           1             1       1.000000
#                                                                    com.higame.brain.twist.tricky.puzzle           1             1       1.000000
#                                                                       com.hg.love.bar.puzzle.sort.merge           5             5       1.000000
#                                                                     com.hg.idleweaponshoptycoon.android           5             5       1.000000
#                                                                             io.supercent.ageofdinosaurs           1             1       1.000000
#                                                                                    com.hellowo.day2life           5             5       1.000000
#                                                                                 com.imagedrome.jihachul           1             1       1.000000
#                                                                                    com.imbc.downloadapp           5             5       1.000000
#                                                                               io.blackcandy.parkemall3d           1             1       1.000000
#                                                                                        com.itknow.bokki           1             1       1.000000
#                                                                           idm.internet.download.manager           4             4       1.000000
#                                                                                      ig.com.hot.pot.qdc           3             3       1.000000
#                                                    com.jigsortscapes.jigsaw.slide.solitaire.puzzle.game           1             1       1.000000
#                                                                                               com.jaumo           1             1       1.000000
#                                                                                    in.mohalla.sharechat           1             1       1.000000
#                                                                                       com.itknow.monpig           1             1       1.000000
#                                                                                 in.playsimple.tripcross           1             1       1.000000
#                                                                                   com.imo.android.imoim           2             2       1.000000
#                                                                                         com.island.card           1             1       1.000000
#                                                                    com.iscreammedia.app.hiclass.android           4             4       1.000000
#                                                                                      com.insta.follower           1             1       1.000000
#                                                                             com.innovate.FilipinoSocial           2             2       1.000000
#                                                                            com.innovate.ColombianSocial           1             1       1.000000
#                                                                              com.thecarousell.Carousell           2             2       1.000000
#                                                                                    com.loop.color.blast           1             1       1.000000
#                                                     gallery.photomanager.picturegalleryapp.imagegallery           1             1       1.000000
#                                                                              com.ntt.summer.ball.puzzle           1             1       1.000000
#                                                                                    com.nebula.crossmath           1             1       1.000000
#                                                                                com.nautilus.realcricket           1             1       1.000000
#                                                                                         com.natris.ilcg           1             1       1.000000
#                                                                                 com.mydogtown.mydogtown           1             1       1.000000
#                                                                                        com.mt.mtxx.mtxx           3             3       1.000000
#                                                                                       com.mrpic.chutcha          12            12       1.000000
#                                                                           com.zimad.puzzle.villa.jigsaw           1             1       1.000000
#                                                                                     com.zione.musictown           1             1       1.000000
#                                                                                com.movieph.bj.playvibes           1             1       1.000000
#                                                                       com.monkeyibrow.worldsoccerchamps           1             1       1.000000
#                                                                                        com.mobirix.tdwt           3             3       1.000000
#                                                                                   com.mobirix.jnggonlns           1             1       1.000000
#                                                                                 com.mobilityware.spider           1             1       1.000000
#                                                                               com.mobilityware.freecell           1             1       1.000000
#                                                             advanced.scientific.calculator.calc991.plus           1             1       1.000000
#                                                           com.zodiac.horoscope.palmreader.scanpalmistry           1             1       1.000000
#                                                                                          com.ncncnative           1             1       1.000000
#                                                                                   com.yoyaworld.sparkle           1             1       1.000000
#                                                                           com.losttemplegames.wordmatch           1             1       1.000000
#                                                                          com.neowiz.game.baseball.clash           2             2       1.000000
#                                                                                            com.www.moji           1             1       1.000000
#                                                                              com.wzdworks.themekeyboard           3             3       1.000000
#                                                                                     com.nt.games.busjam           2             2       1.000000
#                                                                                 com.xiuyou.CannonAttack           1             1       1.000000
#                                                                                       com.xsafe.browser           2             2       1.000000
#                                                                              com.yamystudio.dryCleaning           1             1       1.000000
#                                                                              com.nphokara.billiongostop           1             1       1.000000
#                                                                     com.northerncoldgames.popsiclestack           1             1       1.000000
#                                                                                              com.noithu           1             1       1.000000
#                                                                         com.yolo.differences.findmaster           1             1       1.000000
#                                                                                        com.nmj.readbook           1             1       1.000000
#                                                                                     com.nhn.android.kin           3             3       1.000000
#                                                                      com.nexelon.realmonsterfishing2018           1             1       1.000000
#                                                                                  com.newneek.newneekapp           1             1       1.000000
#                                                                         com.neowiz.games.newmatgogalaxy           2             2       1.000000
#                                                                   com.mobgame.masterchefs.cook.foodsort           1             1       1.000000
#                                                                  com.mnt.game.block.puzzle.brick.tenten           3             3       1.000000
#                                                                                    com.miui.videoplayer          11            11       1.000000
#                                                                                         com.miui.player           8             8       1.000000
#                                                      easynotes.notes.notepad.notebook.privatenotes.note           1             1       1.000000
#                                                                                    com.mattel163.skipbo           1             1       1.000000
#                                                            com.matryoshka.royal.cooking.kitchen.madness           6             6       1.000000
#                                                                            com.matryoshka.cooking.vibes           1             1       1.000000
#                                                                                         com.mate.korean           1             1       1.000000
#                                                                                 com.match.dream.objects           1             1       1.000000
#                                                                                   com.mastobaev.pyramid           1             1       1.000000
#                                                                                com.master.triple3d.find           1             1       1.000000
#                                                                          com.magnitude.magnitudenetwork           1             1       1.000000
#                                                                 find.differences.puzzle.games.spot.free           4             4       1.000000
#                                                                            find.easy.hidden.differences           1             1       1.000000
#                                                                                       com.maf.moneyhero           1             1       1.000000
#                                                                  flower.merge.blossom.puzzle.sort.match           3             3       1.000000
#                                                         found.find.out.hidden.object.games.it.hunt.seek           1             1       1.000000
#                                                 com.love.idol.dressup.doll.makeover.avatar.makeup.games           1             1       1.000000
#                                                                                     com.mbtiapplication           3             3       1.000000
#                                                                              com.mbtkpihzwx.climbtaptap           2             2       1.000000
#                                                                          downloader.video.download.free           1             1       1.000000
#                                                              connect.word.association.sort.puzzle.games           1             1       1.000000
#                                                                        com.miui.global.packageinstaller           3             3       1.000000
#                                                                                com.zymobile.dream.villa           1             1       1.000000
#                                                                            com.mintgames.king.solitaire           1             1       1.000000
#                                                                              com.mintgames.fantasycolor           1             1       1.000000
#                                                                                com.minipact.eartharcade           2             2       1.000000
#                                                                                       com.zzsjkr.google           1             1       1.000000
#                                                            com.miniit.figgerits.cross.word.puzzle.logic           1             1       1.000000
#                                                                                     com.mergegames.myth           2             2       1.000000
#                                                                                  com.miniclip.plagueinc           1             1       1.000000
#                                                            com.mindfig.dream.room.design.home.unpacking           1             1       1.000000
#                                                                          com.minarilabs.mytier.universe           1             1       1.000000
#                                             com.microjoy.number.crush.match.numberzilla.ten.saga.puzzle           1             1       1.000000
#                                                                                 com.mgame.ghostsoulmone           1             1       1.000000
#                                                                              com.metakingdom.mergematch           1             1       1.000000
#                                                                                     Draziw.Button.Mines           3             3       1.000000

# %%
#@title Step 8: Compare IPs - Suspicious vs Normal MTIDs

print("=" * 60)
print("IP Comparison: Suspicious (30+ clicks) vs Normal MTIDs")
print("=" * 60)

# Get clicks per MTID
df_mtid_click_count = df_itct.groupby('mtid').agg({
    'click_timestamp': 'count',
    'ip': 'first',
    'ifa': 'first'
}).reset_index()
df_mtid_click_count.columns = ['mtid', 'click_count', 'ip', 'ifa']

# Flag suspicious MTIDs (30+ clicks)
df_mtid_click_count['is_suspicious'] = df_mtid_click_count['click_count'] >= MIN_CLICK_THRESHOLD

print(f"\nMTID Distribution:")
print(f"  Normal MTIDs (<{MIN_CLICK_THRESHOLD} clicks): {(~df_mtid_click_count['is_suspicious']).sum():,}")
print(f"  Suspicious MTIDs (>={MIN_CLICK_THRESHOLD} clicks): {df_mtid_click_count['is_suspicious'].sum():,}")

# Compare IPs between suspicious and normal
suspicious_ips = set(df_mtid_click_count[df_mtid_click_count['is_suspicious']]['ip'].unique())
normal_ips = set(df_mtid_click_count[~df_mtid_click_count['is_suspicious']]['ip'].unique())
overlap_ips = suspicious_ips & normal_ips
suspicious_only_ips = suspicious_ips - normal_ips

print(f"\nIP Analysis:")
print(f"  IPs with suspicious MTIDs: {len(suspicious_ips):,}")
print(f"  IPs with normal MTIDs only: {len(normal_ips - suspicious_ips):,}")
print(f"  IPs with BOTH suspicious & normal: {len(overlap_ips):,}")
print(f"  IPs with ONLY suspicious MTIDs: {len(suspicious_only_ips):,}")

# Show IPs that ONLY have suspicious MTIDs (high-risk IPs)
if len(suspicious_only_ips) > 0:
    print(f"\nHigh-Risk IPs (only suspicious MTIDs):")
    df_high_risk = df_itct[df_itct['ip'].isin(suspicious_only_ips)].groupby('ip').agg({
        'mtid': 'nunique',
        'ifa': 'nunique',
        'itct_sec': 'mean'
    }).reset_index()
    df_high_risk.columns = ['ip', 'unique_mtids', 'unique_ifas', 'avg_itct_sec']
    df_high_risk = df_high_risk.sort_values('unique_mtids', ascending=False)
    print(df_high_risk.head(20).to_string(index=False))
# Out:
# ============================================================
# IP Comparison: Suspicious (30+ clicks) vs Normal MTIDs
# ============================================================
#
# MTID Distribution:
#   Normal MTIDs (<30 clicks): 183,157
#   Suspicious MTIDs (>=30 clicks): 308
#
# IP Analysis:
#   IPs with suspicious MTIDs: 75
#   IPs with normal MTIDs only: 80,031
#   IPs with BOTH suspicious & normal: 29
#   IPs with ONLY suspicious MTIDs: 46
#
# High-Risk IPs (only suspicious MTIDs):
#              ip  unique_mtids  unique_ifas    avg_itct_sec
#   1.254.164.227             1            1    33226.974684
#  223.39.214.172             1            1      7202.69697
#    183.97.3.134             1            1      115.342857
#    183.97.30.22             1            1       96.514286
#   211.185.5.144             1            1      112.097561
#  211.215.127.89             1            1     1175.268293
#  211.234.226.82             1            1       82.050847
# 211.251.122.132             1            1         106.575
#  211.251.169.50             1            1     1038.257143
#    222.236.3.33             1            1    22081.483871
#   223.39.193.41             1            1      244.878788
#   27.115.145.80             1            1     1507.085714
#  106.101.197.44             1            1      106.705882
#  49.143.147.104             1            1      210.590909
#  58.123.147.166             1            1      145.560976
#   58.123.26.127             1            1      109.685714
#  58.141.235.170             1            1  5438861.239437
#   58.230.109.11             1            1  3721168.914286
#    58.79.38.216             1            1       76.804878
#   59.16.130.110             1            1     2962.672862

# %%
#@title Step 9: Summary & Export

print("=" * 60)
print("SUMMARY")
print("=" * 60)

print(f"\n1. Total clicks analyzed: {len(df_itct):,}")
print(f"2. Unique IFAs: {df_itct['ifa'].nunique():,}")
print(f"3. Unique IPs: {df_itct['ip'].nunique():,}")
print(f"4. Unique MTIDs: {df_itct['mtid'].nunique():,}")
print(f"5. Median ITCT: {df_itct['itct_sec'].median():.2f} seconds")
print(f"6. Suspicious MTIDs ({MIN_CLICK_THRESHOLD}+ clicks): {df_mtid_click_count['is_suspicious'].sum():,}")

# Export to Excel
output_file = 'ODSB-15998_ITCT_analysis_results.xlsx'
with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
    df_ip_clicks.to_excel(writer, sheet_name='IP_Click_Summary', index=False)
    df_ip_mtid_pattern.to_excel(writer, sheet_name='IP_MTID_Pattern', index=False)
    df_pub_ip.head(100).to_excel(writer, sheet_name='Publisher_IP_Top100', index=False)
    df_mtid_click_count.to_excel(writer, sheet_name='MTID_Click_Counts', index=False)
    if len(suspicious_only_ips) > 0:
        df_high_risk.to_excel(writer, sheet_name='High_Risk_IPs', index=False)

print(f"\nResults exported to: {output_file}")
# Out:
# ============================================================
# SUMMARY
# ============================================================
#
# 1. Total clicks analyzed: 387,988
# 2. Unique IFAs: 77,177
# 3. Unique IPs: 80,106
# 4. Unique MTIDs: 183,465
# 5. Median ITCT: 38.00 seconds
# 6. Suspicious MTIDs (30+ clicks): 308
#
# Results exported to: ODSB-15998_ITCT_analysis_results.xlsx
