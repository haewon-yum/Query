# %% [markdown]
# # ODSB-16203: Postback Event Volume Check
#
# Check postback volume for `com.towneers.www`
#
# **Events:** `click_pay_payment`, `click_pay_payment_ad`
#
# **Volume Guidelines:**
# - ≥30/day → Sufficient
# - 10-30/day → Low but usable
# - <10/day → Insufficient

# %%
# Setup
from google.cloud import bigquery
import pandas as pd

client = bigquery.Client(project='moloco-ods')

# Configuration
APP_BUNDLE = 'com.towneers.www'
TARGET_EVENTS = ['click_pay_payment', 'click_pay_payment_ad']
LOOKBACK_DAYS = 7

print(f'App: {APP_BUNDLE}')
print(f'Events: {TARGET_EVENTS}')
print(f'Period: {LOOKBACK_DAYS} days')
# Out:
# App: com.towneers.www
# Events: ['click_pay_payment', 'click_pay_payment_ad']
# Period: 7 days

# %%
# Daily Event Volume
events_str = ", ".join([f"'{e.lower()}'" for e in TARGET_EVENTS])

query = f"""
SELECT
    DATE(timestamp) AS date_utc,
    event.name AS event_name,
    moloco.attributed,
    COUNT(*) AS event_count,
    COUNT(DISTINCT device.ifa) AS unique_devices
FROM `focal-elf-631.prod_stream_view.pb`
WHERE DATE(timestamp) BETWEEN DATE_SUB(CURRENT_DATE(), INTERVAL {LOOKBACK_DAYS} DAY) AND CURRENT_DATE()
    AND app.bundle = '{APP_BUNDLE}'
    AND LOWER(event.name) IN ({events_str})
GROUP BY 1, 2, 3
ORDER BY 1 DESC, 2, 3
"""

df_daily = client.query(query).to_dataframe()
df_daily
# Out:
#       date_utc            event_name  attributed  event_count  unique_devices
# 0   2026-02-06     click_pay_payment       False         3100            2346
# 1   2026-02-06     click_pay_payment        True         4258            1933
# 2   2026-02-06  click_pay_payment_ad       False         1564            1237
# 3   2026-02-06  click_pay_payment_ad        True          883             704
# 4   2026-02-05     click_pay_payment       False        11379            8176
# 5   2026-02-05     click_pay_payment        True        16157            7001
# 6   2026-02-05  click_pay_payment_ad       False         5282            3905
# 7   2026-02-05  click_pay_payment_ad        True         2880            2146
# 8   2026-02-04     click_pay_payment       False        11422            8292
# 9   2026-02-04     click_pay_payment        True        16807            7174
# 10  2026-02-04  click_pay_payment_ad       False         5354            3959
# 11  2026-02-04  click_pay_payment_ad        True         3061            2271
# 12  2026-02-03     click_pay_payment       False        11498            8341
# 13  2026-02-03     click_pay_payment        True        16864            7314
# 14  2026-02-03  click_pay_payment_ad       False         5495            4112
# 15  2026-02-03  click_pay_payment_ad        True         3082            2348
# 16  2026-02-02     click_pay_payment       False        16616           12557
# 17  2026-02-02     click_pay_payment        True        22191            9273
# 18  2026-02-02  click_pay_payment_ad       False         5859            4346
# 19  2026-02-02  click_pay_payment_ad        True         3240            2432
# 20  2026-02-01     click_pay_payment       False         9973            7254
# 21  2026-02-01     click_pay_payment        True        15296            6730
# 22  2026-02-01  click_pay_payment_ad       False         3987            2960
# 23  2026-02-01  click_pay_payment_ad        True         2126            1603
# 24  2026-01-31     click_pay_payment       False         9542            6956
# 25  2026-01-31     click_pay_payment        True        13968            6246
# 26  2026-01-31  click_pay_payment_ad       False         3501            2638
# 27  2026-01-31  click_pay_payment_ad        True         2009            1498
# 28  2026-01-30     click_pay_payment       False        11040            8125
# 29  2026-01-30     click_pay_payment        True        14433            6465
# 30  2026-01-30  click_pay_payment_ad       False         4401            3388
# 31  2026-01-30  click_pay_payment_ad        True         2424            1870

# %%
# Summary (Per Event + Attribution Breakdown, incl. Revenue)
# If attributed, show campaign_id breakdown; otherwise, campaign_id will be NULL
# Also includes per-day and total revenue associated with each row

query_total = f"""
SELECT
    event.name AS event_name,
    moloco.attributed AS is_attributed,
    CASE WHEN moloco.attributed THEN moloco.campaign_id ELSE NULL END AS campaign_id,
    COUNT(*) AS total_events,
    COUNT(DISTINCT device.ifa) AS unique_devices,
    ROUND(COUNT(*) / {LOOKBACK_DAYS}.0, 1) AS avg_daily_events,
    ROUND(COUNT(DISTINCT device.ifa) / {LOOKBACK_DAYS}.0, 1) AS avg_daily_devices,
    COALESCE(SUM(event.revenue_usd.amount), 0) AS total_revenue,
    ROUND(COALESCE(SUM(event.revenue_usd.amount), 0) / {LOOKBACK_DAYS}, 2) AS avg_daily_revenue
FROM `focal-elf-631.prod_stream_view.pb`
WHERE DATE(timestamp) BETWEEN DATE_SUB(CURRENT_DATE(), INTERVAL {LOOKBACK_DAYS} DAY) AND CURRENT_DATE()
    AND app.bundle = '{APP_BUNDLE}'
    AND LOWER(event.name) IN ({events_str})
GROUP BY event.name, moloco.attributed, campaign_id
ORDER BY event.name, moloco.attributed DESC, campaign_id
"""

df_total = client.query(query_total).to_dataframe()

print('=' * 150)
print(f"{'Event':<30} {'Attributed':<12} {'Campaign ID':<16} {'Avg Events/Day':>15} {'Avg Devices/Day':>15} {'Avg Revenue/Day':>18} {'Total Revenue':>15}")
print('=' * 150)

for _, row in df_total.iterrows():
    avg_daily = row['avg_daily_events']
    if avg_daily >= 30:
        status = '✅'
    elif avg_daily >= 10:
        status = '⚠️'
    else:
        status = '❌'
    attr_str = 'Yes' if row['is_attributed'] else 'No'
    campaign_id_str = row['campaign_id'] if row['is_attributed'] else "-"
    print(
        f"{row['event_name']:<30} {attr_str:<12} {str(campaign_id_str):<16} "
        f"{row['avg_daily_events']:>14.1f} {row['avg_daily_devices']:>14.1f} "
        f"{row['avg_daily_revenue']:>17.2f} {row['total_revenue']:>14.2f}  {status}"
    )

print('=' * 150)
print(f"\n✅ >=30/day (Sufficient)  ⚠️ 10-30/day (Low)  ❌ <10/day (Insufficient)")
print(f"\nNote: For RE campaigns, focus on ATTRIBUTED events for model training.")
print(f"      Revenue columns use the sum of event.revenue_usd.amount per row (null values treated as zero).")
# Out:
# ======================================================================================================================================================
# Event                          Attributed   Campaign ID       Avg Events/Day Avg Devices/Day    Avg Revenue/Day   Total Revenue
# ======================================================================================================================================================
# click_pay_payment              Yes          A98pOZZEeLIcpNDZ          769.3          258.1           7666.30       53664.07  ✅
# click_pay_payment              Yes          BFXaj4hUKW7Va5Bi          308.1           99.6           1222.30        8556.13  ✅
# click_pay_payment              Yes          BrmB9MYzcgae9x6M          270.3          102.9           1195.18        8366.28  ✅
# click_pay_payment              Yes          CH1rNyo43DF72uU4            1.3            0.6              4.19          29.35  ❌
# click_pay_payment              Yes          Cuo5P4fyIQnmiIGy            3.0            0.9              6.47          45.31  ❌
# click_pay_payment              Yes          E915nvcav4mey7aE           17.4            6.6             64.83         453.78  ⚠️
# click_pay_payment              Yes          EOC24CmaM2zHunQz            6.7            3.0             15.34         107.38  ❌
# click_pay_payment              Yes          FVg5baQzuZbBG4ZU          615.3          220.7           2096.32       14674.22  ✅
# click_pay_payment              Yes          GV6wJWltTRzzMi8G            1.4            0.4              1.89          13.23  ❌
# click_pay_payment              Yes          Gyqe8pC6ucv5Zsz1           14.0            5.3             33.59         235.11  ⚠️
# click_pay_payment              Yes          HHJzauGDDIIQFsdm           36.0           13.9            142.27         995.90  ✅
# click_pay_payment              Yes          HkOkGf6saJpE6vk1            4.6            1.4             16.99         118.96  ❌
# click_pay_payment              Yes          I0XBmycwRYKmehLG         3428.9         1296.4          18220.71      127544.95  ✅
# click_pay_payment              Yes          JHYGYeac7zkaVxct           31.7            8.9             77.04         539.29  ✅
# click_pay_payment              Yes          JWzvXESsX02fyYKD            6.6            2.1              7.46          52.24  ❌
# click_pay_payment              Yes          K46OIQUyj1KXEfve            2.3            0.9              5.54          38.77  ❌
# click_pay_payment              Yes          KLOxRzFB4icqpk2v            0.1            0.1              0.00           0.00  ❌
# click_pay_payment              Yes          M3tREUz1MojwybKQ           91.6           34.0            286.21        2003.48  ✅
# click_pay_payment              Yes          M6VNxQ68DL91j8hQ          106.9           38.4            828.42        5798.92  ✅
# click_pay_payment              Yes          N10hmsPOU0WfawEZ           47.0           17.0            153.66        1075.59  ✅
# click_pay_payment              Yes          O6DvGIMowTyynGdq          255.7           87.4           1532.00       10724.03  ✅
# click_pay_payment              Yes          O7TeUXnmFsm04vw0         3802.0         1344.3          18468.11      129276.80  ✅
# click_pay_payment              Yes          OaHb8mVytjhEY6t8           40.3           15.1            250.10        1750.73  ✅
# click_pay_payment              Yes          PKRuzEpxIG3FOZw0            0.1            0.1              0.00           0.00  ❌
# click_pay_payment              Yes          PUrSAfhzIzFr8XNF          167.1           57.6            350.28        2451.98  ✅
# click_pay_payment              Yes          PhIRJGV0Wmrf9It0            4.7            1.1             25.07         175.52  ❌
# click_pay_payment              Yes          PxXYkKLQwztSCM2b           22.0            7.4             52.34         366.37  ⚠️
# click_pay_payment              Yes          QLyQXmHq7zLNu5ty            7.9            2.7             48.12         336.83  ❌
# click_pay_payment              Yes          QbzEuAnTCP6drDqK           24.9            9.0             58.88         412.13  ⚠️
# click_pay_payment              Yes          YE9OEunBe2emt0cT           58.4           22.6            162.86        1140.02  ✅
# click_pay_payment              Yes          ZQsMETHavoTiVyuw           94.9           34.9            558.94        3912.60  ✅
# click_pay_payment              Yes          a9jBukYkyAH3pIMg         2314.3          839.1          12026.46       84185.21  ✅
# click_pay_payment              Yes          adbqMRsdYHxmdYls            8.3            2.9             35.44         248.09  ❌
# click_pay_payment              Yes          adpGtaS5jwz2ujlQ            9.1            4.1            169.70        1187.87  ❌
# click_pay_payment              Yes          ay6Lf4kWOwYX1vGy           10.0            3.1             16.95         118.67  ⚠️
# click_pay_payment              Yes          bEqbXZhjyvWePqZZ           50.9           18.4             95.45         668.15  ✅
# click_pay_payment              Yes          bH4Bt9gIMFM8auny           10.6            4.7             42.00         293.99  ⚠️
# click_pay_payment              Yes          e4wIDvEfaQ4UDbvQ           63.0           23.4            300.61        2104.28  ✅
# click_pay_payment              Yes          e6xRILrK0rB9rUgo            5.7            2.0             14.24          99.70  ❌
# click_pay_payment              Yes          ezJIlLh0Lc0kS8lo          161.3           62.1            934.44        6541.09  ✅
# click_pay_payment              Yes          fAEpj71xo5eKRy7Z            7.3            2.3             74.44         521.06  ❌
# click_pay_payment              Yes          fuAv9D7exQo6Zz7Y            0.1            0.1              0.16           1.10  ❌
# click_pay_payment              Yes          gVxjE3mDkScdGgUQ            1.3            1.0              7.84          54.89  ❌
# click_pay_payment              Yes          gk3BZZcy7wxLHlyz           11.9            2.3             54.36         380.49  ⚠️
# click_pay_payment              Yes          hcefDdFZCsqd71zA            1.0            1.0              4.14          28.96  ❌
# click_pay_payment              Yes          htKGMKts6Dn5eEpk         1546.3          561.9           7893.61       55255.26  ✅
# click_pay_payment              Yes          jZvZpo3jKCxLGZiL            3.9            0.9              6.58          46.05  ❌
# click_pay_payment              Yes          jcG4766pV7rbKa1z            3.3            1.4             17.72         124.05  ❌
# click_pay_payment              Yes          k0M410p5xasuJyCY          101.0           36.9            236.27        1653.87  ✅
# click_pay_payment              Yes          kwQI20ABl8UJyXS9            1.6            0.7              7.67          53.72  ❌
# click_pay_payment              Yes          lIzGZp6wU6T229MS           25.9            9.4            184.13        1288.88  ⚠️
# click_pay_payment              Yes          lOlSoQIgR0IXeo3y            4.9            2.3             10.80          75.62  ❌
# click_pay_payment              Yes          n5w4w8kH717Wsy2o            9.7            3.0              7.06          49.42  ❌
# click_pay_payment              Yes          nH3v5eXYh9Joyaj1            1.1            0.9              5.59          39.16  ❌
# click_pay_payment              Yes          naLfOc4evDfMS29y         2523.7          843.0          22277.03      155939.22  ✅
# click_pay_payment              Yes          oIEKgtovzoJLkBtc            0.4            0.3              0.00           0.00  ❌
# click_pay_payment              Yes          qzi4rjCh496HGh7Z           19.4            8.3             73.74         516.18  ⚠️
# click_pay_payment              Yes          rlYiZNqk9XyQyNY6            0.3            0.1              0.00           0.00  ❌
# click_pay_payment              Yes          rqfup2GWJ09dQIdI           78.3           29.0            534.69        3742.81  ✅
# click_pay_payment              Yes          tIFR48Mn0qK5J4IX            0.6            0.3              0.37           2.59  ❌
# click_pay_payment              Yes          uPNV639weIif40DH           22.6            6.7             46.14         322.96  ⚠️
# click_pay_payment              Yes          w00RI1FX07wHmTrV            2.3            1.0              3.27          22.89  ❌
# click_pay_payment              Yes          wk3Fipkl37nAZ7PA           19.7            8.1             60.02         420.11  ⚠️
# click_pay_payment              Yes          ynaVl2jaxIvUDr7i            3.7            1.7             21.48         150.37  ❌
# click_pay_payment              No           -                       12167.0         7240.6         193901.40     1357309.79  ✅
# click_pay_payment_ad           Yes          A98pOZZEeLIcpNDZ          319.6          174.7           7047.45       49332.16  ✅
# click_pay_payment_ad           Yes          BFXaj4hUKW7Va5Bi           29.9           17.3            804.68        5632.79  ⚠️
# click_pay_payment_ad           Yes          BrmB9MYzcgae9x6M           24.0           14.3            632.60        4428.20  ⚠️
# click_pay_payment_ad           Yes          Cuo5P4fyIQnmiIGy            0.3            0.1              5.21          36.48  ❌
# click_pay_payment_ad           Yes          E915nvcav4mey7aE            1.6            1.0             34.39         240.73  ❌
# click_pay_payment_ad           Yes          EOC24CmaM2zHunQz            0.1            0.1              4.92          34.46  ❌
# click_pay_payment_ad           Yes          FVg5baQzuZbBG4ZU           43.1           27.7           1227.46        8592.19  ✅
# click_pay_payment_ad           Yes          HHJzauGDDIIQFsdm            4.4            2.4            112.01         784.04  ❌
# click_pay_payment_ad           Yes          HkOkGf6saJpE6vk1            0.9            0.4             14.18          99.25  ❌
# click_pay_payment_ad           Yes          I0XBmycwRYKmehLG          445.0          281.7          10789.85       75528.94  ✅
# click_pay_payment_ad           Yes          JHYGYeac7zkaVxct            0.4            0.1             29.64         207.50  ❌
# click_pay_payment_ad           Yes          JWzvXESsX02fyYKD            0.1            0.1              1.39           9.70  ❌
# click_pay_payment_ad           Yes          K46OIQUyj1KXEfve            0.1            0.1              4.14          28.95  ❌
# click_pay_payment_ad           Yes          M3tREUz1MojwybKQ            0.9            0.7             18.72         131.01  ❌
# click_pay_payment_ad           Yes          M6VNxQ68DL91j8hQ           24.6           16.7            633.78        4436.43  ⚠️
# click_pay_payment_ad           Yes          N10hmsPOU0WfawEZ            2.1            1.6             58.20         407.42  ❌
# click_pay_payment_ad           Yes          O6DvGIMowTyynGdq           37.1           19.6           1181.88        8273.13  ✅
# click_pay_payment_ad           Yes          O7TeUXnmFsm04vw0          475.4          256.7          12719.99       89039.90  ✅
# click_pay_payment_ad           Yes          OaHb8mVytjhEY6t8            3.4            2.7            101.10         707.69  ❌
# click_pay_payment_ad           Yes          PUrSAfhzIzFr8XNF            2.3            1.7             34.21         239.49  ❌
# click_pay_payment_ad           Yes          PhIRJGV0Wmrf9It0            0.7            0.1             23.37         163.56  ❌
# click_pay_payment_ad           Yes          PxXYkKLQwztSCM2b            0.9            0.3             18.59         130.12  ❌
# click_pay_payment_ad           Yes          QLyQXmHq7zLNu5ty            0.6            0.4             41.39         289.75  ❌
# click_pay_payment_ad           Yes          QbzEuAnTCP6drDqK            0.9            0.7             16.47         115.27  ❌
# click_pay_payment_ad           Yes          YE9OEunBe2emt0cT            1.6            1.1             59.44         416.08  ❌
# click_pay_payment_ad           Yes          ZQsMETHavoTiVyuw            7.6            5.1            192.25        1345.75  ❌
# click_pay_payment_ad           Yes          a9jBukYkyAH3pIMg          323.6          171.7           8659.35       60615.44  ✅
# click_pay_payment_ad           Yes          adbqMRsdYHxmdYls            1.0            0.9             28.51         199.59  ❌
# click_pay_payment_ad           Yes          adpGtaS5jwz2ujlQ            1.7            0.7            144.54        1011.77  ❌
# click_pay_payment_ad           Yes          ay6Lf4kWOwYX1vGy            0.1            0.1              5.15          36.04  ❌
# click_pay_payment_ad           Yes          bEqbXZhjyvWePqZZ            2.6            1.3             26.79         187.54  ❌
# click_pay_payment_ad           Yes          bH4Bt9gIMFM8auny            0.1            0.1              4.87          34.12  ❌
# click_pay_payment_ad           Yes          e4wIDvEfaQ4UDbvQ            7.3            3.7            208.37        1458.56  ❌
# click_pay_payment_ad           Yes          e6xRILrK0rB9rUgo            0.1            0.1              1.38           9.65  ❌
# click_pay_payment_ad           Yes          ezJIlLh0Lc0kS8lo           15.1            7.6            477.04        3339.25  ⚠️
# click_pay_payment_ad           Yes          fAEpj71xo5eKRy7Z            1.7            1.0             64.55         451.85  ❌
# click_pay_payment_ad           Yes          gk3BZZcy7wxLHlyz            0.9            0.3             28.89         202.20  ❌
# click_pay_payment_ad           Yes          htKGMKts6Dn5eEpk          178.1           97.1           5158.44       36109.10  ✅
# click_pay_payment_ad           Yes          jcG4766pV7rbKa1z            1.3            0.3             15.60         109.22  ❌
# click_pay_payment_ad           Yes          k0M410p5xasuJyCY            1.0            0.7             30.10         210.73  ❌
# click_pay_payment_ad           Yes          kwQI20ABl8UJyXS9            0.3            0.3              5.05          35.37  ❌
# click_pay_payment_ad           Yes          lIzGZp6wU6T229MS            4.9            3.0            127.10         889.71  ❌
# click_pay_payment_ad           Yes          lOlSoQIgR0IXeo3y            0.1            0.1              1.96          13.75  ❌
# click_pay_payment_ad           Yes          nH3v5eXYh9Joyaj1            0.4            0.3              5.27          36.89  ❌
# click_pay_payment_ad           Yes          naLfOc4evDfMS29y          855.1          468.3          19774.07      138418.48  ✅
# click_pay_payment_ad           Yes          qzi4rjCh496HGh7Z            1.7            1.0             29.82         208.77  ❌
# click_pay_payment_ad           Yes          rqfup2GWJ09dQIdI           10.0            5.3            373.08        2611.57  ⚠️
# click_pay_payment_ad           Yes          uPNV639weIif40DH            1.1            1.0             17.23         120.61  ❌
# click_pay_payment_ad           Yes          wk3Fipkl37nAZ7PA            1.0            0.7             16.47         115.30  ❌
# click_pay_payment_ad           Yes          ynaVl2jaxIvUDr7i            0.4            0.3              4.23          29.59  ❌
# click_pay_payment_ad           No           -                        5104.7         2774.6         135288.27      947017.92  ✅
# ======================================================================================================================================================
#
# ✅ >=30/day (Sufficient)  ⚠️ 10-30/day (Low)  ❌ <10/day (Insufficient)
#
# Note: For RE campaigns, focus on ATTRIBUTED events for model training.
#       Revenue columns use the sum of event.revenue_usd.amount per row (null values treated as zero).

# %%
# # (Optional) All events for this app
# query_all = f"""
# SELECT event.name, COUNT(*) AS cnt, ROUND(COUNT(*) / {LOOKBACK_DAYS}.0, 1) AS avg_daily
# FROM `focal-elf-631.prod_stream_view.pb`
# WHERE DATE(timestamp) >= DATE_SUB(CURRENT_DATE(), INTERVAL {LOOKBACK_DAYS} DAY)
#     AND app.bundle = '{APP_BUNDLE}'
# GROUP BY 1 ORDER BY 2 DESC LIMIT 20
# """
# client.query(query_all).to_dataframe()
